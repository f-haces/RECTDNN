# %%
# PYTHON IMPORTS
import os
import copy
from tqdm.notebook import trange, tqdm

# IMAGE IMPORTS 
from PIL import Image
import cv2

# DATA IMPORTS 
import numpy as np
import glob

# PLOTTING
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# NEURAL NETWORK
import torch

# MY OWN CLASSES
from TileLocator import *
Image.MAX_IMAGE_PIXELS = 933120000

# %%
data_dir = r"../data/"
model_checkpoint = f"data/RoadLocator/080123.pth"

input_folder  = f"{data_dir}HistoricalFIRMS/"  
output_folder = f"{data_dir}ZZZ_RoadLocator/"

# %%
# Initialize model
model = torch.load(model_checkpoint)
model = model.to("cuda")

# %%
# Iterate over the files in the input folder
for filename in tqdm(os.listdir(input_folder)):
    # Check if the file has a supported image extension
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.tif', '.tiff')):
        # Open the image file
        image_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename[:-3] + "png")
        
        if os.path.exists(output_path):
            continue
        
        print(f"Processing {filename} and saved to {output_path}")
        
        # Apply the process function to the image
        processed_image = split_and_run_cnn(image_path, model, tilesize=1024)
        processed_image = bomb_edges(processed_image)
        processed_image = np.where(processed_image > 0.999, 1, 0)
        image = processed_image * 255
        
        # Save the processed image to the output folder
        cv2.imwrite(output_path, image.astype(np.uint8))
# Out:
#   0%|          | 0/954 [00:00<?, ?it/s]
# Processing 48071C0160E.png and saved to ../data/ZZZ_RoadLocator/48071C0160E.png
# C:\Users\franc\anaconda3\envs\deeplearning\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# D:\Desktop\FIRMsDigitizing\RECTDNN\TileLocator.py:93: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = self.softmax(output)
# Processing 48071C0180E.png and saved to ../data/ZZZ_RoadLocator/48071C0180E.png
# Processing 48071CIND0A.tif and saved to ../data/ZZZ_RoadLocator/48071CIND0A.png
# Processing 4815670001A.jpg and saved to ../data/ZZZ_RoadLocator/4815670001A.png
# Processing 4815780001E.jpg and saved to ../data/ZZZ_RoadLocator/4815780001E.png
# Processing 48157C0020J.tif and saved to ../data/ZZZ_RoadLocator/48157C0020J.png
# Processing 48157C0085J.tif and saved to ../data/ZZZ_RoadLocator/48157C0085J.png
# Processing 48157C0100J.tif and saved to ../data/ZZZ_RoadLocator/48157C0100J.png
# Processing 48157C0105J.tif and saved to ../data/ZZZ_RoadLocator/48157C0105J.png
# Processing 48157C0120J.tif and saved to ../data/ZZZ_RoadLocator/48157C0120J.png
# Processing 48157C0140K.tif and saved to ../data/ZZZ_RoadLocator/48157C0140K.png
# Processing 48157C0255J.tif and saved to ../data/ZZZ_RoadLocator/48157C0255J.png
# Processing 48157C0260J.tif and saved to ../data/ZZZ_RoadLocator/48157C0260J.png
# Processing 48157C0265J.tif and saved to ../data/ZZZ_RoadLocator/48157C0265J.png
# Processing 48157C0270J.tif and saved to ../data/ZZZ_RoadLocator/48157C0270J.png
# Processing 48157C0285L.tif and saved to ../data/ZZZ_RoadLocator/48157C0285L.png
# Processing 48157C0290J.tif and saved to ../data/ZZZ_RoadLocator/48157C0290J.png
# Processing 48157C0305L.tif and saved to ../data/ZZZ_RoadLocator/48157C0305L.png
# Processing 48157CIND0.tif and saved to ../data/ZZZ_RoadLocator/48157CIND0.png
# Processing 48157CIND0A.tif and saved to ../data/ZZZ_RoadLocator/48157CIND0A.png
# Processing 48157CIND0B.tif and saved to ../data/ZZZ_RoadLocator/48157CIND0B.png
# Processing 48201C0005G.tif and saved to ../data/ZZZ_RoadLocator/48201C0005G.png
# Processing 48201C0010G.tif and saved to ../data/ZZZ_RoadLocator/48201C0010G.png
# Processing 48201C0015G.jpg and saved to ../data/ZZZ_RoadLocator/48201C0015G.png
# Processing 48201C0015H.tif and saved to ../data/ZZZ_RoadLocator/48201C0015H.png
# Processing 48201C0015J.tif and saved to ../data/ZZZ_RoadLocator/48201C0015J.png
# Processing 48201C0020G.tif and saved to ../data/ZZZ_RoadLocator/48201C0020G.png
# Processing 48201C0020J.tif and saved to ../data/ZZZ_RoadLocator/48201C0020J.png
# Processing 48201C0025G.tif and saved to ../data/ZZZ_RoadLocator/48201C0025G.png
# Processing 48201C0030G.tif and saved to ../data/ZZZ_RoadLocator/48201C0030G.png
# Processing 48201C0035G.tif and saved to ../data/ZZZ_RoadLocator/48201C0035G.png
# Processing 48201C0040G.tif and saved to ../data/ZZZ_RoadLocator/48201C0040G.png
# Processing 48201C0045G.jpg and saved to ../data/ZZZ_RoadLocator/48201C0045G.png
# Processing 48201C0045H.tif and saved to ../data/ZZZ_RoadLocator/48201C0045H.png
# Processing 48201C0045J.tif and saved to ../data/ZZZ_RoadLocator/48201C0045J.png
# Processing 48201C0050G.jpg and saved to ../data/ZZZ_RoadLocator/48201C0050G.png
# Processing 48201C0050H.tif and saved to ../data/ZZZ_RoadLocator/48201C0050H.png
# Processing 48201C0055G.tif and saved to ../data/ZZZ_RoadLocator/48201C0055G.png
# Processing 48201C0060G.tif and saved to ../data/ZZZ_RoadLocator/48201C0060G.png
# Processing 48201C0065G.tif and saved to ../data/ZZZ_RoadLocator/48201C0065G.png
# Processing 48201C0065J.tif and saved to ../data/ZZZ_RoadLocator/48201C0065J.png
# Processing 48201C0070G.tif and saved to ../data/ZZZ_RoadLocator/48201C0070G.png
# Processing 48201C0070J.tif and saved to ../data/ZZZ_RoadLocator/48201C0070J.png
# Processing 48201C0080G.tif and saved to ../data/ZZZ_RoadLocator/48201C0080G.png
# Processing 48201C0085G.jpg and saved to ../data/ZZZ_RoadLocator/48201C0085G.png
# Processing 48201C0085H.tif and saved to ../data/ZZZ_RoadLocator/48201C0085H.png
# Processing 48201C0090G.tif and saved to ../data/ZZZ_RoadLocator/48201C0090G.png
# Processing 48201C0090J.tif and saved to ../data/ZZZ_RoadLocator/48201C0090J.png
# Processing 48201C0095G.tif and saved to ../data/ZZZ_RoadLocator/48201C0095G.png
# Processing 48201C0100G.tif and saved to ../data/ZZZ_RoadLocator/48201C0100G.png
# Processing 48201C0105G.tif and saved to ../data/ZZZ_RoadLocator/48201C0105G.png
# Processing 48201C0110G.tif and saved to ../data/ZZZ_RoadLocator/48201C0110G.png
# Processing 48201C0115G.tif and saved to ../data/ZZZ_RoadLocator/48201C0115G.png
# Processing 48201C0120G.tif and saved to ../data/ZZZ_RoadLocator/48201C0120G.png
# Processing 48201C0120J.tif and saved to ../data/ZZZ_RoadLocator/48201C0120J.png
# Processing 48201C0125G.tif and saved to ../data/ZZZ_RoadLocator/48201C0125G.png
# Processing 48201C0130G.tif and saved to ../data/ZZZ_RoadLocator/48201C0130G.png
# Processing 48201C0135G.tif and saved to ../data/ZZZ_RoadLocator/48201C0135G.png
# Processing 48201C0140G.tif and saved to ../data/ZZZ_RoadLocator/48201C0140G.png
# Processing 48201C0140J.tif and saved to ../data/ZZZ_RoadLocator/48201C0140J.png
# Processing 48201C0145G.tif and saved to ../data/ZZZ_RoadLocator/48201C0145G.png
# Processing 48201C0150G.tif and saved to ../data/ZZZ_RoadLocator/48201C0150G.png
# Processing 48201C0155G.tif and saved to ../data/ZZZ_RoadLocator/48201C0155G.png
# Processing 48201C0160G.tif and saved to ../data/ZZZ_RoadLocator/48201C0160G.png
# Processing 48201C0160J.tif and saved to ../data/ZZZ_RoadLocator/48201C0160J.png
# Processing 48201C0165G.tif and saved to ../data/ZZZ_RoadLocator/48201C0165G.png
# Processing 48201C0170G.tif and saved to ../data/ZZZ_RoadLocator/48201C0170G.png
# Processing 48201C0170J.tif and saved to ../data/ZZZ_RoadLocator/48201C0170J.png
# Processing 48201C0170L.tif and saved to ../data/ZZZ_RoadLocator/48201C0170L.png
# Processing 48201C0175G.tif and saved to ../data/ZZZ_RoadLocator/48201C0175G.png
# Processing 48201C0180G.tif and saved to ../data/ZZZ_RoadLocator/48201C0180G.png
# Processing 48201C0180J.tif and saved to ../data/ZZZ_RoadLocator/48201C0180J.png
# Processing 48201C0185G.tif and saved to ../data/ZZZ_RoadLocator/48201C0185G.png
# Processing 48201C0185J.tif and saved to ../data/ZZZ_RoadLocator/48201C0185J.png
# Processing 48201C0190G.tif and saved to ../data/ZZZ_RoadLocator/48201C0190G.png
# Processing 48201C0190J.tif and saved to ../data/ZZZ_RoadLocator/48201C0190J.png
# Processing 48201C0195G.tif and saved to ../data/ZZZ_RoadLocator/48201C0195G.png
# Processing 48201C0195J.tif and saved to ../data/ZZZ_RoadLocator/48201C0195J.png
# Processing 48201C0195L.tif and saved to ../data/ZZZ_RoadLocator/48201C0195L.png
# Processing 48201C0195M.tif and saved to ../data/ZZZ_RoadLocator/48201C0195M.png
# Processing 48201C0200G.tif and saved to ../data/ZZZ_RoadLocator/48201C0200G.png
# Processing 48201C0205G.tif and saved to ../data/ZZZ_RoadLocator/48201C0205G.png
# Processing 48201C0205J.tif and saved to ../data/ZZZ_RoadLocator/48201C0205J.png
# Processing 48201C0210G.tif and saved to ../data/ZZZ_RoadLocator/48201C0210G.png
# Processing 48201C0210J.tif and saved to ../data/ZZZ_RoadLocator/48201C0210J.png
# Processing 48201C0215G.tif and saved to ../data/ZZZ_RoadLocator/48201C0215G.png
# Processing 48201C0215J.tif and saved to ../data/ZZZ_RoadLocator/48201C0215J.png
# Processing 48201C0220G.tif and saved to ../data/ZZZ_RoadLocator/48201C0220G.png
# Processing 48201C0220J.tif and saved to ../data/ZZZ_RoadLocator/48201C0220J.png
# Processing 48201C0225G.tif and saved to ../data/ZZZ_RoadLocator/48201C0225G.png
# Processing 48201C0230G.tif and saved to ../data/ZZZ_RoadLocator/48201C0230G.png
# Processing 48201C0230J.tif and saved to ../data/ZZZ_RoadLocator/48201C0230J.png
# Processing 48201C0235G.tif and saved to ../data/ZZZ_RoadLocator/48201C0235G.png
# Processing 48201C0235J.tif and saved to ../data/ZZZ_RoadLocator/48201C0235J.png
# Processing 48201C0235K.tif and saved to ../data/ZZZ_RoadLocator/48201C0235K.png
# Processing 48201C0235L.tif and saved to ../data/ZZZ_RoadLocator/48201C0235L.png
# Processing 48201C0240G.tif and saved to ../data/ZZZ_RoadLocator/48201C0240G.png
# Processing 48201C0240J.tif and saved to ../data/ZZZ_RoadLocator/48201C0240J.png
# Processing 48201C0240L.tif and saved to ../data/ZZZ_RoadLocator/48201C0240L.png
# Processing 48201C0245G.tif and saved to ../data/ZZZ_RoadLocator/48201C0245G.png
# Processing 48201C0245J.tif and saved to ../data/ZZZ_RoadLocator/48201C0245J.png
# Processing 48201C0245K.tif and saved to ../data/ZZZ_RoadLocator/48201C0245K.png
# Processing 48201C0245L.tif and saved to ../data/ZZZ_RoadLocator/48201C0245L.png
# Processing 48201C0250G.tif and saved to ../data/ZZZ_RoadLocator/48201C0250G.png
# Processing 48201C0255G.tif and saved to ../data/ZZZ_RoadLocator/48201C0255G.png
# Processing 48201C0255J.tif and saved to ../data/ZZZ_RoadLocator/48201C0255J.png
# Processing 48201C0260G.tif and saved to ../data/ZZZ_RoadLocator/48201C0260G.png
# Processing 48201C0260J.tif and saved to ../data/ZZZ_RoadLocator/48201C0260J.png
# Processing 48201C0265G.jpg and saved to ../data/ZZZ_RoadLocator/48201C0265G.png
# Processing 48201C0265H.tif and saved to ../data/ZZZ_RoadLocator/48201C0265H.png
# Processing 48201C0265J.tif and saved to ../data/ZZZ_RoadLocator/48201C0265J.png
# Processing 48201C0265L.tif and saved to ../data/ZZZ_RoadLocator/48201C0265L.png
# Processing 48201C0270H.tif and saved to ../data/ZZZ_RoadLocator/48201C0270H.png
# Processing 48201C0270J.tif and saved to ../data/ZZZ_RoadLocator/48201C0270J.png
# Processing 48201C0270L.tif and saved to ../data/ZZZ_RoadLocator/48201C0270L.png
# Processing 48201C0275G.jpg and saved to ../data/ZZZ_RoadLocator/48201C0275G.png
# Processing 48201C0275H.tif and saved to ../data/ZZZ_RoadLocator/48201C0275H.png
# Processing 48201C0280G.tif and saved to ../data/ZZZ_RoadLocator/48201C0280G.png
# Processing 48201C0280J.tif and saved to ../data/ZZZ_RoadLocator/48201C0280J.png
# Processing 48201C0285G.tif and saved to ../data/ZZZ_RoadLocator/48201C0285G.png
# Processing 48201C0290G.jpg and saved to ../data/ZZZ_RoadLocator/48201C0290G.png
# Processing 48201C0290H.tif and saved to ../data/ZZZ_RoadLocator/48201C0290H.png
# Processing 48201C0290J.tif and saved to ../data/ZZZ_RoadLocator/48201C0290J.png
# Processing 48201C0290L.tif and saved to ../data/ZZZ_RoadLocator/48201C0290L.png
# Processing 48201C0290M.tif and saved to ../data/ZZZ_RoadLocator/48201C0290M.png
# Processing 48201C0295G.tif and saved to ../data/ZZZ_RoadLocator/48201C0295G.png
# Processing 48201C0295J.tif and saved to ../data/ZZZ_RoadLocator/48201C0295J.png
# Processing 48201C0295L.tif and saved to ../data/ZZZ_RoadLocator/48201C0295L.png
# Processing 48201C0300G.tif and saved to ../data/ZZZ_RoadLocator/48201C0300G.png
# Processing 48201C0305G.tif and saved to ../data/ZZZ_RoadLocator/48201C0305G.png
# Processing 48201C0305J.tif and saved to ../data/ZZZ_RoadLocator/48201C0305J.png
# Processing 48201C0305K.tif and saved to ../data/ZZZ_RoadLocator/48201C0305K.png
# Processing 48201C0310G.jpg and saved to ../data/ZZZ_RoadLocator/48201C0310G.png
# Processing 48201C0310H.tif and saved to ../data/ZZZ_RoadLocator/48201C0310H.png
# Processing 48201C0310J.tif and saved to ../data/ZZZ_RoadLocator/48201C0310J.png
# Processing 48201C0315G.jpg and saved to ../data/ZZZ_RoadLocator/48201C0315G.png
# Processing 48201C0315H.tif and saved to ../data/ZZZ_RoadLocator/48201C0315H.png
# Processing 48201C0315J.tif and saved to ../data/ZZZ_RoadLocator/48201C0315J.png
# Processing 48201C0315K.tif and saved to ../data/ZZZ_RoadLocator/48201C0315K.png
# Processing 48201C0320G.tif and saved to ../data/ZZZ_RoadLocator/48201C0320G.png
# Processing 48201C0320J.tif and saved to ../data/ZZZ_RoadLocator/48201C0320J.png
# Processing 48201C0320K.tif and saved to ../data/ZZZ_RoadLocator/48201C0320K.png
# Processing 48201C0325G.tif and saved to ../data/ZZZ_RoadLocator/48201C0325G.png
# Processing 48201C0330G.jpg and saved to ../data/ZZZ_RoadLocator/48201C0330G.png
# Processing 48201C0330H.tif and saved to ../data/ZZZ_RoadLocator/48201C0330H.png
# Processing 48201C0330J.tif and saved to ../data/ZZZ_RoadLocator/48201C0330J.png
# Processing 48201C0335G.jpg and saved to ../data/ZZZ_RoadLocator/48201C0335G.png
# Processing 48201C0335H.tif and saved to ../data/ZZZ_RoadLocator/48201C0335H.png
# Processing 48201C0335J.tif and saved to ../data/ZZZ_RoadLocator/48201C0335J.png
# Processing 48201C0340G.tif and saved to ../data/ZZZ_RoadLocator/48201C0340G.png
# Processing 48201C0340J.tif and saved to ../data/ZZZ_RoadLocator/48201C0340J.png
# Processing 48201C0345G.tif and saved to ../data/ZZZ_RoadLocator/48201C0345G.png
# Processing 48201C0345J.tif and saved to ../data/ZZZ_RoadLocator/48201C0345J.png
# Processing 48201C0350G.jpg and saved to ../data/ZZZ_RoadLocator/48201C0350G.png
# Processing 48201C0350H.tif and saved to ../data/ZZZ_RoadLocator/48201C0350H.png
# Processing 48201C0355G.jpg and saved to ../data/ZZZ_RoadLocator/48201C0355G.png
# Processing 48201C0355H.tif and saved to ../data/ZZZ_RoadLocator/48201C0355H.png
# Processing 48201C0360G.tif and saved to ../data/ZZZ_RoadLocator/48201C0360G.png
# Processing 48201C0360J.tif and saved to ../data/ZZZ_RoadLocator/48201C0360J.png
# Processing 48201C0360L.tif and saved to ../data/ZZZ_RoadLocator/48201C0360L.png
# Processing 48201C0365G.tif and saved to ../data/ZZZ_RoadLocator/48201C0365G.png
# Processing 48201C0370G.tif and saved to ../data/ZZZ_RoadLocator/48201C0370G.png
# Processing 48201C0370L.tif and saved to ../data/ZZZ_RoadLocator/48201C0370L.png
# Processing 48201C0375G.tif and saved to ../data/ZZZ_RoadLocator/48201C0375G.png
# Processing 48201C0380G.tif and saved to ../data/ZZZ_RoadLocator/48201C0380G.png
# Processing 48201C0380J.tif and saved to ../data/ZZZ_RoadLocator/48201C0380J.png
# Processing 48201C0380L.tif and saved to ../data/ZZZ_RoadLocator/48201C0380L.png
# Processing 48201C0380M.tif and saved to ../data/ZZZ_RoadLocator/48201C0380M.png
# Processing 48201C0385G.tif and saved to ../data/ZZZ_RoadLocator/48201C0385G.png
# Processing 48201C0385J.tif and saved to ../data/ZZZ_RoadLocator/48201C0385J.png
# Processing 48201C0385L.tif and saved to ../data/ZZZ_RoadLocator/48201C0385L.png
# Processing 48201C0385M.tif and saved to ../data/ZZZ_RoadLocator/48201C0385M.png
# Processing 48201C0390G.tif and saved to ../data/ZZZ_RoadLocator/48201C0390G.png
# Processing 48201C0390J.tif and saved to ../data/ZZZ_RoadLocator/48201C0390J.png
# Processing 48201C0390L.tif and saved to ../data/ZZZ_RoadLocator/48201C0390L.png
# Processing 48201C0390M.tif and saved to ../data/ZZZ_RoadLocator/48201C0390M.png
# Processing 48201C0395J.tif and saved to ../data/ZZZ_RoadLocator/48201C0395J.png
# Processing 48201C0395L.tif and saved to ../data/ZZZ_RoadLocator/48201C0395L.png
# Processing 48201C0395M.tif and saved to ../data/ZZZ_RoadLocator/48201C0395M.png
# Processing 48201C0405J.tif and saved to ../data/ZZZ_RoadLocator/48201C0405J.png
# Processing 48201C0405L.tif and saved to ../data/ZZZ_RoadLocator/48201C0405L.png
# Processing 48201C0410J.tif and saved to ../data/ZZZ_RoadLocator/48201C0410J.png
# Processing 48201C0410L.tif and saved to ../data/ZZZ_RoadLocator/48201C0410L.png
# Processing 48201C0415J.tif and saved to ../data/ZZZ_RoadLocator/48201C0415J.png
# Processing 48201C0415L.tif and saved to ../data/ZZZ_RoadLocator/48201C0415L.png
# Processing 48201C0415M.tif and saved to ../data/ZZZ_RoadLocator/48201C0415M.png
# Processing 48201C0420J.tif and saved to ../data/ZZZ_RoadLocator/48201C0420J.png
# Processing 48201C0420K.tif and saved to ../data/ZZZ_RoadLocator/48201C0420K.png
# Processing 48201C0420L.tif and saved to ../data/ZZZ_RoadLocator/48201C0420L.png
# Processing 48201C0420M.tif and saved to ../data/ZZZ_RoadLocator/48201C0420M.png
# Processing 48201C0420N.tif and saved to ../data/ZZZ_RoadLocator/48201C0420N.png
# Processing 48201C0430J.tif and saved to ../data/ZZZ_RoadLocator/48201C0430J.png
# Processing 48201C0430K.tif and saved to ../data/ZZZ_RoadLocator/48201C0430K.png
# Processing 48201C0430L.tif and saved to ../data/ZZZ_RoadLocator/48201C0430L.png
# Processing 48201C0435J.tif and saved to ../data/ZZZ_RoadLocator/48201C0435J.png
# Processing 48201C0435L.tif and saved to ../data/ZZZ_RoadLocator/48201C0435L.png
# Processing 48201C0440J.tif and saved to ../data/ZZZ_RoadLocator/48201C0440J.png
# Processing 48201C0440K.tif and saved to ../data/ZZZ_RoadLocator/48201C0440K.png
# Processing 48201C0440L.tif and saved to ../data/ZZZ_RoadLocator/48201C0440L.png
# Processing 48201C0440M.tif and saved to ../data/ZZZ_RoadLocator/48201C0440M.png
# Processing 48201C0445J.tif and saved to ../data/ZZZ_RoadLocator/48201C0445J.png
# Processing 48201C0445K.tif and saved to ../data/ZZZ_RoadLocator/48201C0445K.png
# Processing 48201C0445L.tif and saved to ../data/ZZZ_RoadLocator/48201C0445L.png
# Processing 48201C0455J.tif and saved to ../data/ZZZ_RoadLocator/48201C0455J.png
# Processing 48201C0460J.tif and saved to ../data/ZZZ_RoadLocator/48201C0460J.png
# Processing 48201C0460L.tif and saved to ../data/ZZZ_RoadLocator/48201C0460L.png
# Processing 48201C0465J.tif and saved to ../data/ZZZ_RoadLocator/48201C0465J.png
# Processing 48201C0465K.tif and saved to ../data/ZZZ_RoadLocator/48201C0465K.png
# Processing 48201C0465L.tif and saved to ../data/ZZZ_RoadLocator/48201C0465L.png
# Processing 48201C0470J.tif and saved to ../data/ZZZ_RoadLocator/48201C0470J.png
# Processing 48201C0480J.tif and saved to ../data/ZZZ_RoadLocator/48201C0480J.png
# Processing 48201C0480L.tif and saved to ../data/ZZZ_RoadLocator/48201C0480L.png
# Processing 48201C0485J.tif and saved to ../data/ZZZ_RoadLocator/48201C0485J.png
# Processing 48201C0485L.tif and saved to ../data/ZZZ_RoadLocator/48201C0485L.png
# Processing 48201C0490J.tif and saved to ../data/ZZZ_RoadLocator/48201C0490J.png
# Processing 48201C0495J.tif and saved to ../data/ZZZ_RoadLocator/48201C0495J.png
# Processing 48201C0505J.tif and saved to ../data/ZZZ_RoadLocator/48201C0505J.png
# Processing 48201C0505L.tif and saved to ../data/ZZZ_RoadLocator/48201C0505L.png
# Processing 48201C0510J.tif and saved to ../data/ZZZ_RoadLocator/48201C0510J.png
# Processing 48201C0515J.tif and saved to ../data/ZZZ_RoadLocator/48201C0515J.png
# Processing 48201C0515L.tif and saved to ../data/ZZZ_RoadLocator/48201C0515L.png
# Processing 48201C0520J.tif and saved to ../data/ZZZ_RoadLocator/48201C0520J.png
# Processing 48201C0530J.tif and saved to ../data/ZZZ_RoadLocator/48201C0530J.png
# Processing 48201C0535J.tif and saved to ../data/ZZZ_RoadLocator/48201C0535J.png
# Processing 48201C0540J.tif and saved to ../data/ZZZ_RoadLocator/48201C0540J.png
# Processing 48201C0545J.tif and saved to ../data/ZZZ_RoadLocator/48201C0545J.png
# Processing 48201C0555J.tif and saved to ../data/ZZZ_RoadLocator/48201C0555J.png
# Processing 48201C0565J.tif and saved to ../data/ZZZ_RoadLocator/48201C0565J.png
# Processing 48201C0580J.tif and saved to ../data/ZZZ_RoadLocator/48201C0580J.png
# Processing 48201C0580L.tif and saved to ../data/ZZZ_RoadLocator/48201C0580L.png
# Processing 48201C0585J.tif and saved to ../data/ZZZ_RoadLocator/48201C0585J.png
# Processing 48201C0585L.tif and saved to ../data/ZZZ_RoadLocator/48201C0585L.png
# Processing 48201C0590J.tif and saved to ../data/ZZZ_RoadLocator/48201C0590J.png
# Processing 48201C0595J.tif and saved to ../data/ZZZ_RoadLocator/48201C0595J.png
# Processing 48201C0595L.tif and saved to ../data/ZZZ_RoadLocator/48201C0595L.png
# Processing 48201C0605J.tif and saved to ../data/ZZZ_RoadLocator/48201C0605J.png
# Processing 48201C0605L.tif and saved to ../data/ZZZ_RoadLocator/48201C0605L.png
# Processing 48201C0610J.tif and saved to ../data/ZZZ_RoadLocator/48201C0610J.png
# Processing 48201C0610L.tif and saved to ../data/ZZZ_RoadLocator/48201C0610L.png
# Processing 48201C0615J.tif and saved to ../data/ZZZ_RoadLocator/48201C0615J.png
# Processing 48201C0615L.tif and saved to ../data/ZZZ_RoadLocator/48201C0615L.png
# Processing 48201C0620J.tif and saved to ../data/ZZZ_RoadLocator/48201C0620J.png
# Processing 48201C0620L.tif and saved to ../data/ZZZ_RoadLocator/48201C0620L.png
# Processing 48201C0630J.tif and saved to ../data/ZZZ_RoadLocator/48201C0630J.png
# Processing 48201C0630L.tif and saved to ../data/ZZZ_RoadLocator/48201C0630L.png
# Processing 48201C0635J.tif and saved to ../data/ZZZ_RoadLocator/48201C0635J.png
# Processing 48201C0635K.tif and saved to ../data/ZZZ_RoadLocator/48201C0635K.png
# Processing 48201C0635L.tif and saved to ../data/ZZZ_RoadLocator/48201C0635L.png
# Processing 48201C0640J.tif and saved to ../data/ZZZ_RoadLocator/48201C0640J.png
# Processing 48201C0640L.tif and saved to ../data/ZZZ_RoadLocator/48201C0640L.png
# Processing 48201C0645J.tif and saved to ../data/ZZZ_RoadLocator/48201C0645J.png
# Processing 48201C0655J.tif and saved to ../data/ZZZ_RoadLocator/48201C0655J.png
# Processing 48201C0655K.tif and saved to ../data/ZZZ_RoadLocator/48201C0655K.png
# Processing 48201C0655L.tif and saved to ../data/ZZZ_RoadLocator/48201C0655L.png
# Processing 48201C0660J.tif and saved to ../data/ZZZ_RoadLocator/48201C0660J.png
# Processing 48201C0660K.tif and saved to ../data/ZZZ_RoadLocator/48201C0660K.png
# Processing 48201C0660L.tif and saved to ../data/ZZZ_RoadLocator/48201C0660L.png
# Processing 48201C0665J.tif and saved to ../data/ZZZ_RoadLocator/48201C0665J.png
# Processing 48201C0665K.tif and saved to ../data/ZZZ_RoadLocator/48201C0665K.png
# Processing 48201C0665L.tif and saved to ../data/ZZZ_RoadLocator/48201C0665L.png
# Processing 48201C0670J.tif and saved to ../data/ZZZ_RoadLocator/48201C0670J.png
# Processing 48201C0670K.tif and saved to ../data/ZZZ_RoadLocator/48201C0670K.png
# Processing 48201C0670L.tif and saved to ../data/ZZZ_RoadLocator/48201C0670L.png
# Processing 48201C0680J.tif and saved to ../data/ZZZ_RoadLocator/48201C0680J.png
# Processing 48201C0680K.tif and saved to ../data/ZZZ_RoadLocator/48201C0680K.png
# Processing 48201C0685J.tif and saved to ../data/ZZZ_RoadLocator/48201C0685J.png
# Processing 48201C0690J.tif and saved to ../data/ZZZ_RoadLocator/48201C0690J.png
# Processing 48201C0690K.tif and saved to ../data/ZZZ_RoadLocator/48201C0690K.png
# Processing 48201C0690L.tif and saved to ../data/ZZZ_RoadLocator/48201C0690L.png
# Processing 48201C0690M.tif and saved to ../data/ZZZ_RoadLocator/48201C0690M.png
# Processing 48201C0695J.tif and saved to ../data/ZZZ_RoadLocator/48201C0695J.png
# Processing 48201C0695L.tif and saved to ../data/ZZZ_RoadLocator/48201C0695L.png
# Processing 48201C0705J.tif and saved to ../data/ZZZ_RoadLocator/48201C0705J.png
# Processing 48201C0705L.tif and saved to ../data/ZZZ_RoadLocator/48201C0705L.png
# Processing 48201C0710J.tif and saved to ../data/ZZZ_RoadLocator/48201C0710J.png
# Processing 48201C0710L.tif and saved to ../data/ZZZ_RoadLocator/48201C0710L.png
# Processing 48201C0715J.tif and saved to ../data/ZZZ_RoadLocator/48201C0715J.png
# Processing 48201C0715L.tif and saved to ../data/ZZZ_RoadLocator/48201C0715L.png
# Processing 48201C0720J.tif and saved to ../data/ZZZ_RoadLocator/48201C0720J.png
# Processing 48201C0720L.tif and saved to ../data/ZZZ_RoadLocator/48201C0720L.png
# Processing 48201C0730J.tif and saved to ../data/ZZZ_RoadLocator/48201C0730J.png
# Processing 48201C0730L.tif and saved to ../data/ZZZ_RoadLocator/48201C0730L.png
# Processing 48201C0735J.tif and saved to ../data/ZZZ_RoadLocator/48201C0735J.png
# Processing 48201C0735K.tif and saved to ../data/ZZZ_RoadLocator/48201C0735K.png
# Processing 48201C0735L.tif and saved to ../data/ZZZ_RoadLocator/48201C0735L.png
# Processing 48201C0740J.tif and saved to ../data/ZZZ_RoadLocator/48201C0740J.png
# Processing 48201C0740L.tif and saved to ../data/ZZZ_RoadLocator/48201C0740L.png
# Processing 48201C0745J.tif and saved to ../data/ZZZ_RoadLocator/48201C0745J.png
# Processing 48201C0745K.tif and saved to ../data/ZZZ_RoadLocator/48201C0745K.png
# Processing 48201C0745L.tif and saved to ../data/ZZZ_RoadLocator/48201C0745L.png
# Processing 48201C0755J.tif and saved to ../data/ZZZ_RoadLocator/48201C0755J.png
# Processing 48201C0755L.tif and saved to ../data/ZZZ_RoadLocator/48201C0755L.png
# Processing 48201C0760J.tif and saved to ../data/ZZZ_RoadLocator/48201C0760J.png
# Processing 48201C0760L.tif and saved to ../data/ZZZ_RoadLocator/48201C0760L.png
# Processing 48201C0760M.tif and saved to ../data/ZZZ_RoadLocator/48201C0760M.png
# Processing 48201C0765J.tif and saved to ../data/ZZZ_RoadLocator/48201C0765J.png
# Processing 48201C0765L.tif and saved to ../data/ZZZ_RoadLocator/48201C0765L.png
# Processing 48201C0770J.tif and saved to ../data/ZZZ_RoadLocator/48201C0770J.png
# Processing 48201C0770L.tif and saved to ../data/ZZZ_RoadLocator/48201C0770L.png
# Processing 48201C0770M.tif and saved to ../data/ZZZ_RoadLocator/48201C0770M.png
# Processing 48201C0785J.tif and saved to ../data/ZZZ_RoadLocator/48201C0785J.png
# Processing 48201C0805J.tif and saved to ../data/ZZZ_RoadLocator/48201C0805J.png
# Processing 48201C0810J.tif and saved to ../data/ZZZ_RoadLocator/48201C0810J.png
# Processing 48201C0810K.tif and saved to ../data/ZZZ_RoadLocator/48201C0810K.png
# Processing 48201C0830J.tif and saved to ../data/ZZZ_RoadLocator/48201C0830J.png
# Processing 48201C0830K.tif and saved to ../data/ZZZ_RoadLocator/48201C0830K.png
# Processing 48201C0835J.tif and saved to ../data/ZZZ_RoadLocator/48201C0835J.png
# Processing 48201C0835K.tif and saved to ../data/ZZZ_RoadLocator/48201C0835K.png
# Processing 48201C0840J.tif and saved to ../data/ZZZ_RoadLocator/48201C0840J.png
# Processing 48201C0840K.tif and saved to ../data/ZZZ_RoadLocator/48201C0840K.png
# Processing 48201C0845J.tif and saved to ../data/ZZZ_RoadLocator/48201C0845J.png
# Processing 48201C0845K.tif and saved to ../data/ZZZ_RoadLocator/48201C0845K.png
# Processing 48201C0845L.tif and saved to ../data/ZZZ_RoadLocator/48201C0845L.png
# Processing 48201C0855J.tif and saved to ../data/ZZZ_RoadLocator/48201C0855J.png
# Processing 48201C0855K.tif and saved to ../data/ZZZ_RoadLocator/48201C0855K.png
# Processing 48201C0860J.tif and saved to ../data/ZZZ_RoadLocator/48201C0860J.png
# Processing 48201C0860K.tif and saved to ../data/ZZZ_RoadLocator/48201C0860K.png
# Processing 48201C0865J.tif and saved to ../data/ZZZ_RoadLocator/48201C0865J.png
# Processing 48201C0865K.tif and saved to ../data/ZZZ_RoadLocator/48201C0865K.png
# Processing 48201C0865L.tif and saved to ../data/ZZZ_RoadLocator/48201C0865L.png
# Processing 48201C0870J.tif and saved to ../data/ZZZ_RoadLocator/48201C0870J.png
# Processing 48201C0870K.tif and saved to ../data/ZZZ_RoadLocator/48201C0870K.png
# Processing 48201C0870L.tif and saved to ../data/ZZZ_RoadLocator/48201C0870L.png
# Processing 48201C0880J.tif and saved to ../data/ZZZ_RoadLocator/48201C0880J.png
# Processing 48201C0880K.tif and saved to ../data/ZZZ_RoadLocator/48201C0880K.png
# Processing 48201C0880L.tif and saved to ../data/ZZZ_RoadLocator/48201C0880L.png
# Processing 48201C0885J.tif and saved to ../data/ZZZ_RoadLocator/48201C0885J.png
# Processing 48201C0885K.tif and saved to ../data/ZZZ_RoadLocator/48201C0885K.png
# Processing 48201C0885L.tif and saved to ../data/ZZZ_RoadLocator/48201C0885L.png
# Processing 48201C0885M.tif and saved to ../data/ZZZ_RoadLocator/48201C0885M.png
# Processing 48201C0890J.tif and saved to ../data/ZZZ_RoadLocator/48201C0890J.png
# Processing 48201C0890L.tif and saved to ../data/ZZZ_RoadLocator/48201C0890L.png
# Processing 48201C0895J.tif and saved to ../data/ZZZ_RoadLocator/48201C0895J.png
# Processing 48201C0895L.tif and saved to ../data/ZZZ_RoadLocator/48201C0895L.png
# Processing 48201C0895M.tif and saved to ../data/ZZZ_RoadLocator/48201C0895M.png
# Processing 48201C0905J.tif and saved to ../data/ZZZ_RoadLocator/48201C0905J.png
# Processing 48201C0905L.tif and saved to ../data/ZZZ_RoadLocator/48201C0905L.png
# Processing 48201C0905M.tif and saved to ../data/ZZZ_RoadLocator/48201C0905M.png
# Processing 48201C0910J.tif and saved to ../data/ZZZ_RoadLocator/48201C0910J.png
# Processing 48201C0910L.tif and saved to ../data/ZZZ_RoadLocator/48201C0910L.png
# Processing 48201C0915J.tif and saved to ../data/ZZZ_RoadLocator/48201C0915J.png
# Processing 48201C0915L.tif and saved to ../data/ZZZ_RoadLocator/48201C0915L.png
# Processing 48201C0915M.tif and saved to ../data/ZZZ_RoadLocator/48201C0915M.png
# Processing 48201C0920J.tif and saved to ../data/ZZZ_RoadLocator/48201C0920J.png
# Processing 48201C0920L.tif and saved to ../data/ZZZ_RoadLocator/48201C0920L.png
# Processing 48201C0930J.tif and saved to ../data/ZZZ_RoadLocator/48201C0930J.png
# Processing 48201C0930L.tif and saved to ../data/ZZZ_RoadLocator/48201C0930L.png
# Processing 48201C0935J.tif and saved to ../data/ZZZ_RoadLocator/48201C0935J.png
# Processing 48201C0935L.tif and saved to ../data/ZZZ_RoadLocator/48201C0935L.png
# Processing 48201C0940J.tif and saved to ../data/ZZZ_RoadLocator/48201C0940J.png
# Processing 48201C0940L.tif and saved to ../data/ZZZ_RoadLocator/48201C0940L.png
# Processing 48201C0945J.tif and saved to ../data/ZZZ_RoadLocator/48201C0945J.png
# Processing 48201C0945L.tif and saved to ../data/ZZZ_RoadLocator/48201C0945L.png
# Processing 48201C0955J.tif and saved to ../data/ZZZ_RoadLocator/48201C0955J.png
# Processing 48201C0955L.tif and saved to ../data/ZZZ_RoadLocator/48201C0955L.png
# Processing 48201C0960J.tif and saved to ../data/ZZZ_RoadLocator/48201C0960J.png
# Processing 48201C0960L.tif and saved to ../data/ZZZ_RoadLocator/48201C0960L.png
# Processing 48201C0960M.tif and saved to ../data/ZZZ_RoadLocator/48201C0960M.png
# Processing 48201C0965J.tif and saved to ../data/ZZZ_RoadLocator/48201C0965J.png
# Processing 48201C0965L.tif and saved to ../data/ZZZ_RoadLocator/48201C0965L.png
# Processing 48201C0970J.tif and saved to ../data/ZZZ_RoadLocator/48201C0970J.png
# Processing 48201C0970L.tif and saved to ../data/ZZZ_RoadLocator/48201C0970L.png
# Processing 48201C0970M.tif and saved to ../data/ZZZ_RoadLocator/48201C0970M.png
# Processing 48201C0985J.tif and saved to ../data/ZZZ_RoadLocator/48201C0985J.png
# Processing 48201C0985L.tif and saved to ../data/ZZZ_RoadLocator/48201C0985L.png
# Processing 48201C1005J.tif and saved to ../data/ZZZ_RoadLocator/48201C1005J.png
# Processing 48201C1005K.tif and saved to ../data/ZZZ_RoadLocator/48201C1005K.png
# Processing 48201C1005L.tif and saved to ../data/ZZZ_RoadLocator/48201C1005L.png
# Processing 48201C1010J.tif and saved to ../data/ZZZ_RoadLocator/48201C1010J.png
# Processing 48201C1010K.tif and saved to ../data/ZZZ_RoadLocator/48201C1010K.png
# Processing 48201C1010L.tif and saved to ../data/ZZZ_RoadLocator/48201C1010L.png
# Processing 48201C1030J.tif and saved to ../data/ZZZ_RoadLocator/48201C1030J.png
# Processing 48201C1030K.tif and saved to ../data/ZZZ_RoadLocator/48201C1030K.png
# Processing 48201C1030L.tif and saved to ../data/ZZZ_RoadLocator/48201C1030L.png
# Processing 48201C1035J.tif and saved to ../data/ZZZ_RoadLocator/48201C1035J.png
# Processing 48201C1035K.tif and saved to ../data/ZZZ_RoadLocator/48201C1035K.png
# Processing 48201C1045J.tif and saved to ../data/ZZZ_RoadLocator/48201C1045J.png
# Processing 48201C1045K.tif and saved to ../data/ZZZ_RoadLocator/48201C1045K.png
# Processing 48201C1055J.tif and saved to ../data/ZZZ_RoadLocator/48201C1055J.png
# Processing 48201C1055K.tif and saved to ../data/ZZZ_RoadLocator/48201C1055K.png
# Processing 48201C1060J.tif and saved to ../data/ZZZ_RoadLocator/48201C1060J.png
# Processing 48201C1060K.tif and saved to ../data/ZZZ_RoadLocator/48201C1060K.png
# Processing 48201C1060L.tif and saved to ../data/ZZZ_RoadLocator/48201C1060L.png
# Processing 48201C1065J.tif and saved to ../data/ZZZ_RoadLocator/48201C1065J.png
# Processing 48201C1065K.tif and saved to ../data/ZZZ_RoadLocator/48201C1065K.png
# Processing 48201C1065L.tif and saved to ../data/ZZZ_RoadLocator/48201C1065L.png
# Processing 48201C1070J.tif and saved to ../data/ZZZ_RoadLocator/48201C1070J.png
# Processing 48201C1070K.tif and saved to ../data/ZZZ_RoadLocator/48201C1070K.png
# Processing 48201C1070L.tif and saved to ../data/ZZZ_RoadLocator/48201C1070L.png
# Processing 48201C1080J.tif and saved to ../data/ZZZ_RoadLocator/48201C1080J.png
# Processing 48201C1080L.tif and saved to ../data/ZZZ_RoadLocator/48201C1080L.png
# Processing 48201C1085J.tif and saved to ../data/ZZZ_RoadLocator/48201C1085J.png
# Processing 48201C1085L.tif and saved to ../data/ZZZ_RoadLocator/48201C1085L.png
# Processing 48201C1090J.tif and saved to ../data/ZZZ_RoadLocator/48201C1090J.png
# Processing 48201C1090K.tif and saved to ../data/ZZZ_RoadLocator/48201C1090K.png
# Processing 48201C1090L.tif and saved to ../data/ZZZ_RoadLocator/48201C1090L.png
# Processing 48201C1095J.tif and saved to ../data/ZZZ_RoadLocator/48201C1095J.png
# Processing 48201C1095L.tif and saved to ../data/ZZZ_RoadLocator/48201C1095L.png
# Processing 48201C1105J.tif and saved to ../data/ZZZ_RoadLocator/48201C1105J.png
# Processing 48201C1105L.tif and saved to ../data/ZZZ_RoadLocator/48201C1105L.png
# Processing 48201CIND0.tif and saved to ../data/ZZZ_RoadLocator/48201CIND0.png
# Processing 48201CIND0A.tif and saved to ../data/ZZZ_RoadLocator/48201CIND0A.png
# Processing 48201CIND0B.tif and saved to ../data/ZZZ_RoadLocator/48201CIND0B.png
# Processing 48201CIND0C.tif and saved to ../data/ZZZ_RoadLocator/48201CIND0C.png
# Processing 48201CIND0D.tif and saved to ../data/ZZZ_RoadLocator/48201CIND0D.png
# Processing 48201CIND0E.tif and saved to ../data/ZZZ_RoadLocator/48201CIND0E.png
# Processing 48201CIND0F.tif and saved to ../data/ZZZ_RoadLocator/48201CIND0F.png
# Processing 48201CIND0_0990.jpg and saved to ../data/ZZZ_RoadLocator/48201CIND0_0990.png
# Processing 48201CIND0_0992.tif and saved to ../data/ZZZ_RoadLocator/48201CIND0_0992.png
# Processing 48201CIND0_1196.tif and saved to ../data/ZZZ_RoadLocator/48201CIND0_1196.png
# Processing 48201CSTD01.jpg and saved to ../data/ZZZ_RoadLocator/48201CSTD01.png
# Processing 48201CSTD02.jpg and saved to ../data/ZZZ_RoadLocator/48201CSTD02.png
# Processing 48201CSTD1.tif and saved to ../data/ZZZ_RoadLocator/48201CSTD1.png
# Processing 48201CSTD2.tif and saved to ../data/ZZZ_RoadLocator/48201CSTD2.png
# Processing 48339CIND0.tif and saved to ../data/ZZZ_RoadLocator/48339CIND0.png
# Processing 48473C0175E.tif and saved to ../data/ZZZ_RoadLocator/48473C0175E.png
# Processing 48473CIND0A.tif and saved to ../data/ZZZ_RoadLocator/48473CIND0A.png
# Processing 4854560005.tif and saved to ../data/ZZZ_RoadLocator/4854560005.png
# Processing 4854560005B.jpg and saved to ../data/ZZZ_RoadLocator/4854560005B.png
# Processing 4854560005D.tif and saved to ../data/ZZZ_RoadLocator/4854560005D.png
# Processing 4854560010.tif and saved to ../data/ZZZ_RoadLocator/4854560010.png
# Processing 4854560010B.jpg and saved to ../data/ZZZ_RoadLocator/4854560010B.png
# Processing 4854560010C.jpg and saved to ../data/ZZZ_RoadLocator/4854560010C.png
# Processing 4854560010D.jpg and saved to ../data/ZZZ_RoadLocator/4854560010D.png
# Processing 4854560015.tif and saved to ../data/ZZZ_RoadLocator/4854560015.png
# Processing 4854560015B.jpg and saved to ../data/ZZZ_RoadLocator/4854560015B.png
# Processing 4854560015D.jpg and saved to ../data/ZZZ_RoadLocator/4854560015D.png
# Processing 4854560015E.tif and saved to ../data/ZZZ_RoadLocator/4854560015E.png
# Processing 4854560020B.jpg and saved to ../data/ZZZ_RoadLocator/4854560020B.png
# Processing 485456A.tif and saved to ../data/ZZZ_RoadLocator/485456A.png
# Processing 485456FND0.tif and saved to ../data/ZZZ_RoadLocator/485456FND0.png
# Processing 485456IND0_0279.jpg and saved to ../data/ZZZ_RoadLocator/485456IND0_0279.png
# Processing 485456IND0_0982.jpg and saved to ../data/ZZZ_RoadLocator/485456IND0_0982.png
# Processing 485456IND0_1185.jpg and saved to ../data/ZZZ_RoadLocator/485456IND0_1185.png
# Processing 485466.tif and saved to ../data/ZZZ_RoadLocator/485466.png
# Processing 4854660001C.jpg and saved to ../data/ZZZ_RoadLocator/4854660001C.png
# Processing 485466B.tif and saved to ../data/ZZZ_RoadLocator/485466B.png
# Processing 4854680005.tif and saved to ../data/ZZZ_RoadLocator/4854680005.png
# Processing 4854680005C.jpg and saved to ../data/ZZZ_RoadLocator/4854680005C.png
# Processing 4854680005D.tif and saved to ../data/ZZZ_RoadLocator/4854680005D.png
# Processing 4854680005E.tif and saved to ../data/ZZZ_RoadLocator/4854680005E.png
# Processing 4854680010.tif and saved to ../data/ZZZ_RoadLocator/4854680010.png
# Processing 4854680010C.jpg and saved to ../data/ZZZ_RoadLocator/4854680010C.png
# Processing 4854680015.tif and saved to ../data/ZZZ_RoadLocator/4854680015.png
# Processing 4854680015C.jpg and saved to ../data/ZZZ_RoadLocator/4854680015C.png
# Processing 4854680020.tif and saved to ../data/ZZZ_RoadLocator/4854680020.png
# Processing 4854680020C.jpg and saved to ../data/ZZZ_RoadLocator/4854680020C.png
# Processing 485468A.tif and saved to ../data/ZZZ_RoadLocator/485468A.png
# Processing 485468B.tif and saved to ../data/ZZZ_RoadLocator/485468B.png
# Processing 485468IND0_0483.jpg and saved to ../data/ZZZ_RoadLocator/485468IND0_0483.png
# Processing 485468STD0.tif and saved to ../data/ZZZ_RoadLocator/485468STD0.png
# Processing 485487.tif and saved to ../data/ZZZ_RoadLocator/485487.png
# Processing 4854870005D.jpg and saved to ../data/ZZZ_RoadLocator/4854870005D.png
# Processing 4854870010D.jpg and saved to ../data/ZZZ_RoadLocator/4854870010D.png
# Processing 485487B.tif and saved to ../data/ZZZ_RoadLocator/485487B.png
# Processing 485487C.tif and saved to ../data/ZZZ_RoadLocator/485487C.png
# Processing 485487IND0_1185.jpg and saved to ../data/ZZZ_RoadLocator/485487IND0_1185.png
# Processing 4854880001B.jpg and saved to ../data/ZZZ_RoadLocator/4854880001B.png
# Processing 4854880002B.jpg and saved to ../data/ZZZ_RoadLocator/4854880002B.png
# Processing 4854880003B.jpg and saved to ../data/ZZZ_RoadLocator/4854880003B.png
# Processing 4854880005.tif and saved to ../data/ZZZ_RoadLocator/4854880005.png
# Processing 4854880005C.tif and saved to ../data/ZZZ_RoadLocator/4854880005C.png
# Processing 4854880005D.tif and saved to ../data/ZZZ_RoadLocator/4854880005D.png
# Processing 4854880010.tif and saved to ../data/ZZZ_RoadLocator/4854880010.png
# Processing 4854880010C.tif and saved to ../data/ZZZ_RoadLocator/4854880010C.png
# Processing 4854880010D.tif and saved to ../data/ZZZ_RoadLocator/4854880010D.png
# Processing 4854880011C.tif and saved to ../data/ZZZ_RoadLocator/4854880011C.png
# Processing 4854880011D.tif and saved to ../data/ZZZ_RoadLocator/4854880011D.png
# Processing 4854880013C.tif and saved to ../data/ZZZ_RoadLocator/4854880013C.png
# Processing 4854880013D.tif and saved to ../data/ZZZ_RoadLocator/4854880013D.png
# Processing 4854880020C.tif and saved to ../data/ZZZ_RoadLocator/4854880020C.png
# Processing 4854880020D.tif and saved to ../data/ZZZ_RoadLocator/4854880020D.png
# Processing 4854880025.tif and saved to ../data/ZZZ_RoadLocator/4854880025.png
# Processing 4854880025C.tif and saved to ../data/ZZZ_RoadLocator/4854880025C.png
# Processing 4854880025D.tif and saved to ../data/ZZZ_RoadLocator/4854880025D.png
# Processing 4854880030.tif and saved to ../data/ZZZ_RoadLocator/4854880030.png
# Processing 4854880030C.jpg and saved to ../data/ZZZ_RoadLocator/4854880030C.png
# Processing 4854880030D.tif and saved to ../data/ZZZ_RoadLocator/4854880030D.png
# Processing 4854880030E.tif and saved to ../data/ZZZ_RoadLocator/4854880030E.png
# Processing 485488A.tif and saved to ../data/ZZZ_RoadLocator/485488A.png
# Processing 485488IND0.tif and saved to ../data/ZZZ_RoadLocator/485488IND0.png
# Processing 485488IND0_0583.jpg and saved to ../data/ZZZ_RoadLocator/485488IND0_0583.png
# Processing 485488IND0_0990.tif and saved to ../data/ZZZ_RoadLocator/485488IND0_0990.png
# Processing 485491.tif and saved to ../data/ZZZ_RoadLocator/485491.png
# Processing 4854910001E.jpg and saved to ../data/ZZZ_RoadLocator/4854910001E.png
# Processing 485491B.tif and saved to ../data/ZZZ_RoadLocator/485491B.png
# Processing 485491C.tif and saved to ../data/ZZZ_RoadLocator/485491C.png
# Processing 485491D.tif and saved to ../data/ZZZ_RoadLocator/485491D.png
# Processing 4855070005B.tif and saved to ../data/ZZZ_RoadLocator/4855070005B.png
# Processing 485510.tif and saved to ../data/ZZZ_RoadLocator/485510.png
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3140\1528576917.py in <module>
#      13
#      14         # Apply the process function to the image
# ---> 15         processed_image = split_and_run_cnn(image_path, model, tilesize=1024)
#      16         processed_image = bomb_edges(processed_image)
#      17         processed_image = np.where(processed_image > 0.999, 1, 0)
#
# D:\Desktop\FIRMsDigitizing\RECTDNN\TileLocator.py in split_and_run_cnn(image_path, model, tilesize)
#     283
#     284     # Load the image
# --> 285     image = Image.open(image_path)
#     286
#     287     if np.asarray(image).ndim == 3:
#
# ~\anaconda3\envs\deeplearning\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    3029         warnings.warn(message)
#    3030     raise UnidentifiedImageError(
# -> 3031         "cannot identify image file %r" % (filename if filename else fp)
#    3032     )
#    3033
#
# UnidentifiedImageError: cannot identify image file '../data/HistoricalFIRMS/485510.tif'
