# %%
# NOTEBOOK IMPORTS
import os, glob, warnings, pickle, re
import numpy as np
from shutil import copyfile, rmtree
from datetime import datetime
from fuzzywuzzy import process

import traceback

# IMAGE IMPORTS
from PIL import Image
import cv2

# GIS IMPORTS
from affinetransformation import *
from affine import Affine
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon, LineString, Point, MultiPoint, box
import rasterio as rio
import contextily as cx

# IMAGE IMPORTS
from skimage.morphology import skeletonize
from skimage import img_as_bool, img_as_ubyte


# PLOTTING IMPORTS
import matplotlib.pyplot as plt

# CUSTOM UTILITIES
from IndexUtils import * 
from TileUtils import *

# TILED INFERENCE
import sahi
from sahi import AutoDetectionModel
from sahi.predict import get_sliced_prediction, predict
sahi.utils.cv.IMAGE_EXTENSIONS = ['.jpg', '.jpeg', '.png', '.tiff', '.bmp', '.tif']

Image.MAX_IMAGE_PIXELS = 933120000
warnings.filterwarnings("ignore")
initialize = False

# %matplotlib widget

from fuzzywuzzy import process
from rapidfuzz import fuzz
import easyocr
from tqdm.autonotebook import tqdm

# %%
proc_dir = r"D:\RECTDNN\processing\2024-10-11_15-08-46\\"
outputs_dir  = os.path.join(proc_dir, "Outputs")
output_struct_dir = os.path.join(outputs_dir, "IndexCoords.pkl")
with open(output_struct_dir, 'rb') as f:
    gen_dict = pickle.load(f)

# %%
def resize_image(image, size=512):
    
    if image.ndim == 3:
        image = image[:, :, 0]

    # Get the current dimensions of the image
    height, width = image.shape
    
    # Calculate the scaling factor to resize the longest side to 512 pixels
    if height > width:
        scale_factor = size / height
    else:
        scale_factor = size / width
    
    # Compute new dimensions
    new_height = int(height * scale_factor)
    new_width = int(width * scale_factor)
    
    # Resize the image using OpenCV
    resized_img = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_LINEAR)
    
    return resized_img

# %%
def prepImageForReading(img):
    image = np.asarray(img, dtype=np.uint8)
    if np.max(image) < 255:
        image = image * 255
    return image

# %%
import re
from dateutil import parser

# %%
# Out:
# 'FEBRUARY  2, 2006'

# %%
parser.parse(re.sub(",", ", ", "'FEBRWARY 16 , 1995'").replace("|", ""))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 parser.parse(re.sub(",", ", ", "'FEBRWARY 16 , 1995'").replace("|", ""))
#
# File c:\Users\fhacesga\Anaconda3\envs\yolo\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File c:\Users\fhacesga\Anaconda3\envs\yolo\lib\site-packages\dateutil\parser\_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     640 res, skipped_tokens = self._parse(timestr, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#     646     raise ParserError("String does not contain a date: %s", timestr)
#
# ParserError: Unknown string format: 'FEBRWARY 16 ,  1995'

# %%
def extract_date(text):
    """
    # Step 1: Use regular expressions to look for date-like patterns
    # Looking for both numeric dates (e.g. 9/10/92) and written dates (e.g. April 2, 1990)
    date_regex = r'(\d{1,2}[\/\-]\d{1,2}[\/\-]\d{2,4})|([A-Za-z]+\s+\d{1,2},\s+\d{4})'
    
    # Step 2: Search the text for any potential date patterns
    match = re.search(date_regex, text)
    
    if match:
        date_str = match.group(0)
        try:
            # Step 3: Parse the matched date string
            return parser.parse(date_str)
        except ValueError:
            pass  # If parsing fails, it will return None later on
    """
    # Step 4: Fallback: Try fuzzy parsing on the entire string if no match is found
    try:
        return parser.parse(re.sub(",", ", ", text).replace("|", ""), fuzzy=True)
    except:
        return None  # Return None if no valid date is found
    

def extractDate(img, filter_values=None, verbose=False, year_cutoff=2020, ini_year=1965):
    image = prepImageForReading(img)
    texts = reader.readtext(cv2.cvtColor(resize_image(image, size=1024), cv2.COLOR_GRAY2BGR), detail=0, width_ths=50)
    texts_search = [s if re.search(r'[a-zA-Z]', s) else "" for s in texts]
    dates = [extract_date(a) for a in texts_search]

    if len(dates) == 0:
        return None, texts

    if filter_values is None:
        return dates, texts
    
    filtered_dates = []
    for a in np.where(np.array(dates) != None)[0].tolist():
        for b in filter_values:
            _, v = process.extractOne(b, texts[a-1].split(" "))
            if verbose:
                print(texts[a], texts[a-1], b, v)
            v = np.max([a, v])        
        if v > 0.7:
            filtered_dates.append(dates[a])

    filtered_dates = [a for a in filtered_dates if a.year < year_cutoff]
    filtered_dates = [a for a in filtered_dates if a.year > ini_year]

    if len(filtered_dates) == 0:
        return None, texts

    return filtered_dates, texts
    
    # dates = [a for a in dates if a is not None]
    
    

    return dates, " ".join(texts)
'''
for i, (k, v) in tqdm(enumerate(gen_dict.items()), total=len(gen_dict.items())):
    if len(v['legend']) == 0:
        continue
    dates_found, text_found = extractDate(v['legend'][0]['data'], filter_values=['revised', 'effective'])

    print(dates_found)
    if dates_found is None:
        print(text_found)
'''
# Out:
#   0%|          | 0/171 [00:00<?, ?it/s]
# [datetime.datetime(1990, 4, 2, 0, 0)]
# [datetime.datetime(1989, 7, 17, 0, 0)]
# [datetime.datetime(1990, 9, 28, 0, 0)]
# None
# ['NATiONal FLOOD INSURANCE PROGRAm', 'FIRM', 'FLOOD INSURANCE RATE MAP', 'BEXAR COUNTY, TEXAS', '(UNINCORPORATED AREAS) #', 'MAP INDEX', 'PANELS PRintedr2s. 50. 66.76: 100.125. 150.', '156.160.105,470.180.186. 190-195.226.240 ,', '245.250 3275.286.295.305.310,315.220.350.', '375. 3805385, 390, 395, 426. 450. 476. 480 ,', '485. 4903495. 525. 550. 575,800. 625. 650, 676', 'CommunITy-PaNEL  NUMBERS', '480035 0001-0675', 'EFFECTIVE DATE:', 'GTOBER  16,1984', 'Federal Emergency Management Agency', '2', '450,']
# [datetime.datetime(1991, 10, 16, 0, 0)]
# [datetime.datetime(1985, 11, 15, 0, 0)]
# [datetime.datetime(1986, 1, 3, 0, 0)]
# [datetime.datetime(1989, 1, 5, 0, 0)]
# [datetime.datetime(1986, 4, 2, 0, 0)]
# [datetime.datetime(1978, 6, 27, 0, 0)]
# [datetime.datetime(1991, 7, 2, 0, 0)]
# [datetime.datetime(1990, 8, 2, 0, 0)]
# [datetime.datetime(1984, 11, 15, 0, 0)]
# [datetime.datetime(1983, 12, 15, 0, 0)]
# [datetime.datetime(1980, 7, 2, 0, 0)]
# [datetime.datetime(1982, 3, 1, 0, 0)]
# [datetime.datetime(1998, 11, 20, 0, 0)]
# [datetime.datetime(1995, 6, 2, 0, 0)]
# [datetime.datetime(1981, 5, 19, 0, 0)]
# [datetime.datetime(1995, 7, 17, 0, 0)]
# [datetime.datetime(1992, 9, 30, 0, 0)]
# [datetime.datetime(1981, 2, 24, 0, 0)]
# [datetime.datetime(1988, 2, 4, 0, 0)]
# [datetime.datetime(1982, 3, 30, 0, 0)]
# [datetime.datetime(1985, 9, 27, 0, 0)]
# [datetime.datetime(1982, 9, 21, 0, 0)]
# [datetime.datetime(1985, 9, 27, 0, 0)]
# [datetime.datetime(1987, 9, 4, 0, 0)]
# [datetime.datetime(1979, 12, 11, 0, 0)]
# [datetime.datetime(2002, 1, 4, 0, 0)]
# [datetime.datetime(2006, 2, 2, 0, 0)]
# [datetime.datetime(2007, 6, 18, 0, 0)]
# [datetime.datetime(2010, 9, 29, 0, 0)]
# None
# ['National Fleow inSurANJE PROeRA=', 'FIRM', 'Flo0b |NSWRANCE RATE MAP', 'BEXAR CQUNTY', 'TEXAS ANI', 'INCORPOR', 'CRI', 'AREAS', '(SeE TRBLE SHcwN AbovE For', '{ISTG 0f', 'Communities}', 'MApinde', 'FANELS', 'SRiNtet: 20 8024orC,20,25,91,98,105,', '3o7n20[30,134,40,15,735.165,3iC.276,127_', '203411,733,734,340,141,241,343,341.151', '353,2544236,257,258,258,241.207,262,364,', '766,267.368045,776,277,278,278,81,282,783,', '167,386,2574088,789,271,252.292,298,301,362,', '3c,206303051312.3123130', '34035.', '40640y216', '477,418_', '0424244', '60,227,', '400,451,450450_', '456/30X58759.4614014014067o847o', '3I7L479/40,481,453,04,*8049s,505,0', '35,,23533,560,573.380621,583,285,.324,90,', '386,401+02,603,84760,6C3,60S,615,620,876,', '627', '{2843173773,636,030/37 60064,', '3n27 664.688473800,736,35,766,730.782,', '600 87,810,e3,220450,*80', 'Map VWMBER', '4BC29Codoo', 'EFFECTIVE DAJE:', 'FEBRWARY 16 , 1995', 'Anergejcy Managemeit Ageccy', 'TPBlE', '130 5']
# [datetime.datetime(1982, 1, 6, 0, 0)]
# [datetime.datetime(1977, 10, 25, 0, 0)]
# None
# ['NATional FLOOD Insurance PROGRam', 'FIRM', 'FLOOD INSURANCE RATE MAP', 'CITY OF ', 'MISSOURL CITY, TEXAS', 'FORT BEND_AND   HARRIS', 'COUNTIES', 'MAP INDEX', 'PANELS PRINTED: 5,10,45,20,25', 'COMMUNITY-PANEL NUMBERS', '48030470001-0025', 'MApREVISED:', 'DECE BER 77, 1987', 'Federal Emergency Management Agency']
# [datetime.datetime(2015, 5, 10, 20, 0), datetime.datetime(1986, 6, 3, 0, 0)]
# [datetime.datetime(1999, 9, 22, 0, 0)]
# [datetime.datetime(1992, 5, 4, 0, 0)]
# [datetime.datetime(1984, 3, 1, 0, 0)]
# [datetime.datetime(1981, 8, 17, 0, 0)]
# [datetime.datetime(2015, 5, 4, 0, 0)]
# [datetime.datetime(1983, 4, 4, 0, 0)]
# [datetime.datetime(2002, 12, 6, 0, 0)]
# [datetime.datetime(1983, 10, 18, 0, 0)]
# [datetime.datetime(1991, 3, 4, 0, 0)]
# [datetime.datetime(1983, 2, 16, 0, 0)]
# [datetime.datetime(1991, 3, 4, 0, 0)]
# [datetime.datetime(2001, 11, 7, 0, 0)]
# [datetime.datetime(2014, 4, 2, 0, 0)]
# [datetime.datetime(2017, 12, 21, 0, 0)]
# [datetime.datetime(2007, 11, 2, 0, 0)]
# [datetime.datetime(2000, 4, 20, 0, 0)]
# [datetime.datetime(2007, 6, 18, 0, 0)]
# [datetime.datetime(2013, 10, 16, 0, 0)]
# [datetime.datetime(2014, 6, 9, 0, 0)]
# [datetime.datetime(2015, 5, 4, 0, 0)]
# [datetime.datetime(2017, 1, 6, 0, 0)]
# [datetime.datetime(2019, 5, 2, 0, 0)]
# [datetime.datetime(1990, 9, 28, 0, 0)]
# [datetime.datetime(1992, 9, 30, 0, 0)]
# [datetime.datetime(1996, 11, 22, 0, 0)]
# [datetime.datetime(2010, 12, 17, 0, 0)]
# [datetime.datetime(2012, 4, 3, 0, 0)]
# [datetime.datetime(1993, 9, 22, 0, 0)]
# [datetime.datetime(2009, 2, 18, 0, 0)]
# [datetime.datetime(1979, 2, 9, 0, 0)]
# [datetime.datetime(2015, 5, 10, 20, 0), datetime.datetime(1982, 9, 28, 0, 0)]
# None
# ['National FLOOD INSURANcE PRoGrAM', 'FIRM', 'FLOOD INSURANCE RATE MAP', 'CITY OF', 'BAYTOWN,', 'TEXAS', 'HARRIS   AND', 'CHAMBERS   COUNTIES', 'MAP INDEX', 'PANELS PRINTED: 5,410,15', 'COMMUnity-PANEL  NUMBERS', '485456 0001-0015', 'MAP REVISED:', 'NOWEMBER 15, 1985', 'Federal Emergency Management Agency']
# [datetime.datetime(2015, 5, 10, 20, 0), datetime.datetime(1983, 4, 18, 0, 0)]
# [datetime.datetime(1992, 5, 4, 0, 0)]
# [datetime.datetime(2002, 12, 6, 0, 0)]
# [datetime.datetime(1992, 5, 4, 0, 0)]
# None
# ['NATiOnal FLOOD INSURANCE PROGRAM', 'FIRM', 'FLOOD INSURANCE RATE MAP', 'CITY OF', 'GALVESTON ,  TEXAS', 'GALVESTON COUNTY', 'MAP INDEX', 'PANELS PRINTED: 5,15,25,35', '40,45', 'COMMUNITy-PaneL  NUMBERS', '485469 0001-0045', 'MAP  REVISED:', 'UNE 13, 1980', 'U8 DEPARTMENT OF HOUSING', 'AND URBAN DEVELOPMENT', 'FEDERAL INSURANCE ADMINISTRATION']
# [datetime.datetime(1983, 8, 15, 0, 0)]
# [datetime.datetime(1984, 10, 16, 0, 0)]
# [datetime.datetime(1993, 7, 6, 0, 0)]
# [datetime.datetime(2002, 12, 6, 0, 0)]
# [datetime.datetime(1983, 5, 2, 0, 0)]
# [datetime.datetime(1992, 8, 18, 0, 0)]
# [datetime.datetime(1983, 10, 1, 0, 0)]
# None
# ['NaTIonal FLOOD INSURAncE ProgRAM', 'FIRM', 'FLOOD INSURANCE  RATE MAP', 'GALVESTON COUNTY,', 'TEXAS', '(UNINCORPORATED AREAS)', 'MAP INDEX', 'PoNg $', 'PRINTED; 10,26,27-29,35, 60. 65', '75,80,85190.95.99.1003105', '883', '127.131.1357445. 150, 155,', '3', '195,200 205_210_', '317z', '221"230.235', '240, 241, 242*265. 270.272. 274 278', 'COMMUnIty-PANEL NUMBERS', '485470,0001-0316', 'MAP REVISED:', 'OVEMBER 16,1990', 'Federal Emergency Management Agency', '181.']
# [datetime.datetime(2015, 5, 10, 20, 0), datetime.datetime(1983, 4, 4, 0, 0)]
# [datetime.datetime(2003, 1, 2, 0, 0), datetime.datetime(1983, 4, 4, 0, 0)]
# [datetime.datetime(1983, 2, 16, 0, 0)]
# None
# ['NAtional FLOOD   INSURANCEPROGRAM', 'FLOOD  INSURANCE  RATE MAPS', 'CITY OF', 'LA MARQUE;', 'TEXAS', 'GALVESTON COUNTY', 'INdEX TO MAP PAGES', 'THROUGH 10', 'PAGES PRINTED: 5,10', 'community-PANEL MUMBER', '485486 0001-0010', 'MAP REVISED', 'OCTOBER 6,71978', 'Ill=', 'U.S. DEPARTMENT OF HOUSING', 'AND URBAN DEVELOPMENT', 'FEDERAL INSURANCE AdMINISTRATION', '1']
# [datetime.datetime(1985, 11, 1, 0, 0)]
# [datetime.datetime(2011, 5, 10, 13, 0), datetime.datetime(1999, 9, 22, 0, 0)]
# [datetime.datetime(2013, 5, 10, 0, 0), datetime.datetime(1983, 5, 2, 0, 0)]
# [datetime.datetime(2011, 5, 10, 13, 0)]
# None
# ['NA TIbNal FLOOD HNSuRAncE Program', 'FIRM', 'FLOOD INSURANCE RATE MAP', 'CITY OF', 'TEXAS CITY, TEXAS', 'GALVESTON COUNTY', 'MAP INDEX', 'PANELS PrinTeO: 5,9,10,13,25, 30', '35, 45,50', 'ComMunITY-PANEL NWKBERS', '485514 0001-0o50', 'MAP PEVASED:', 'MAy 4, 1592', 'Federal Emergency Munagenent Agercy']
# [datetime.datetime(1983, 5, 2, 0, 0)]
# None
# ['National FLOOD INSurANCE PROGRam', 'FIRM', 'FLOOD  INSURANCE RATE MAP', 'CITY O=', 'WEBSTER;', 'HARRIS   COUNTY', '7', 'MAP', 'PANELS PRINTED: 2,3', 'COMMUnIty-PANEL NUMBERS', '485516 0001-0003', 'MAP REVISED:', 'FEBRUARY 27, 198 1', 'federat emergency management agency', 'federal insurance administration', 'INDEX)']
# [datetime.datetime(1982, 1, 22, 0, 0)]
# None
# ['departMeNT OF HouSing And URBAN OEVELOPMENT', 'Federal Insuraiict Administration', 'CiTYAOFALAMO HEI GHTS ,WT=', '(BEXARCO', 'MAP INdEX', 'FIA Flooo HAZARO BOUNOARY MAPS', 'No h', 'Aier']
# None
# ['OEPARTMENT OF Housing AND URBAN DEveLOFMENT', 'Federal Incurance Administration', 'FLOOD HAZaRD BOUNDARY MAP H .01-02', 'Map INDEX', 'CITY OF CASTLE HILLS, TX', '(BEXAR CO.)', 'NV', 'community nO .. 480037A', '0']
# None
# ['OEPaRTMENT Of Housihg And UabaN develOpment', 'Federal Insurance Adminisxahon', 'CATX OF CONVERSE', '(BEXAR CO0 , )', 'MAP InOEX', 'FIA Flooo HAZARD BOUROARY MAPS', 'No H   01402', '80038']
# None
# ['DEPARTMENT Of Kousing And URBAN DEVELOPMENT', 'Federal lnsurance: Administration', 'CityOF   GREY FOREST  TX', '(BEXAR cO,', 'MAP INOEX', 'FIA FLOOD HAZARD BOUNOARY MAPS', 'No H   01', '480037']
# None
# ['DEPARTMENT OF housing And URBAN OEVELOpment', 'Fedenl |nurencs Admicbbation', 'FLOOD hazard @0UNdaRy Map H', 'Map INdEX 0', 'Town OF HOLLYWOOD PARK , TX', '(BEXAR CO', '0C', 'community mo. 480040A']
# None
# ['DEPARTMENT OF Housing And URBAN DEVELOFMENT', 'Federal Inurance Administration', '0', 'FLOOD HAZARD BOUNDARY MAp H . 0t', 'Map INdEX @', 'C|TY OF KIRBY , TX', '(3EXAR CO , )', 'coamunity nO.480041A', 'to"']
# None
# ['OEPArTMeNT OF Housing And UABAN OEVELOPMENT', 'Federal Insurance Administration', 'C|TYOF KIRBY', '7', 'BEXAR CO', 'MAP INOEX', 'FIA Flood_HAZARO BQUNDARY MAPS', 'No. H (48 )029(3705)0 1', 'Area,elyible Ior Federally assisted Ilood Insurance', 'CORPORATE LimitS']
# None
# ['OEPARTMENT OF Housing ANd URBAN DEVELOPMENT', 'Federal  Insurance  Administration', 'city OF LEON VALLEY, TX', '(BEXAR CO . )', 'MAP INDEX', 'FIA FlooO KAZARO BOUNOARY MAPS', 'No H', '01-02', 'Mc"']
# None
# ['DEPARTMENT OF HOuSing And Urban DEVELOPMENT', 'Federal Insurance Ad ministration', 'FLOOD HAZARd ROUNDARY MAP H . 0 1-03', 'Map IndEX  Vae', 'OF LIVE OaK', '(BEXAR CJ', 'community nO. 480043A', 'gh', 'Ktcor', 'Co']
# None
# ['OEPARTMENT OF HOuSing ANd URBAN OEVELOPMENT', 'Federal  nsurance Administration', 'city  O LIVE OAK,', 'BEXAR CO', 'MAP INOEX', 'FIA FlOOd HAZARD BOUNOARY MAPS', 'No, H,', '0 1 -03', 'La']
# None
# ["DEPARTMENT Of Housing Anq URBAN' OEVELOPMenT", 'Federal Insurance Administration', 'City OF SELMA , TX', '(BEXAR , COMAL AND GUADALUPE COS.', 'MAP indeX', "FIA Flooo HAZARO' BOUNDARY MAPS", 'No. H   01', 'Nicr']
# None
# ['DEPARTMENT OF Housing AND URBAN DEVELOFMENT', 'Federal Insurance Administration', 'FLOOD HAZaRd BOUNDARY MAP H . 01', "0' Hap INDEX", 'TOWN OF SHAVANO PARK; TX', '(BEXAR CO:) :', 'community No . 480047A']
# None
# ['DEPARTMENT OF housing And UrbAN DEVELOPMENT', 'Federal Insurance Administration', 'FLOOD HAZARD BOUNDARY HAP H . 01-02', 'Map InDEX', '0$', 'city OF TERRELL HVLLS , TX', '(BEXAR Co . )', 'community KO. 4800484', 'tO']
# None
# ['DEPARTMENT OF Kousing And URBAN DEVELOPMENT', 'Federal Insurance Administration', 'FLOOD HAZARd BOUNDARY MAP H - 01+06', 'Map IN DEX (aeee', 'CITY  OF   UNI VERSAL CTY , TX', '(BEXAR CO . )', 'CoMm unity nO. 480049a', 'Eto']
# None
# ['DEPARTMENT OF HOUSing And URBAN DEVELOPMENT', 'Federal Insurance Administration', 'FLOOd HAZARd BOUKDARY MAP H : /01 191', 'Map INdEX', '0', 'CITY OF PEARLAND; TX', '(BRAZORIA AND HARRIS COS:)', 'community O . 480077A', 'Kto']
# None
# ['OEPARTMEMT OF Housing And URBAN OEVELOPMENT', 'Federal Insuronce` Administration', 'CiTY JF   PEARLAND', "BRAZORI A AND' HARRIs Cos. )", 'MAP INOEX', 'FIA FlOOD HAZARO BOUNOARY MAPS', 'No k', '01-18', 'MIci']
# None
# ['DEPARTMENT OF HouSing And URBAN DEVELOPMENT', 'Fedezal Insurance Administration', 'FLOOD HAZARD BOUNDARY MaP H . 01-02', 'Map INDEX', 'OF Cl BOLO', '( GUADALUPE CO ,_', 'community nO . 4802674', 'an', 'tOcm']
# None
# ['DEPARTMENT OF HOUSing AND URBAN DEVELOPMENT,', 'Federal Insurance Administration', 'FLOOD HAZARd BOUndarY MAp H . 01-06', 'CJhAp InDEX +', 'CGTy OE SCHERTZ   TX', '(COMAL, GUADALUPE AND BEXAR COS:)', 'commumity nO . 480269A']
# None
# ['DEPARTMENT Of housing ANd URBAN OEVELOPMENT', 'Federal Insurance Administraton]', "city4 0F' SCHERTZ", '#Nn', 'TX', '(GUADALUPE  CO', 'MAP INDEX', 'FIA FLoOO HAZARO 8OUNOARY MAPS', 'No H', '48 187  6237  01-04', '48667']
# None
# ['DEPARTMENT OF HOUSinG And UrbAN developmeNT', 'Federal Insurance Administration', 'FLOOD HAzard BOUNDARY MAP H : 01-100', 'FLOOD insurance RaTE MAP / . 01-100', 'Map INDEX', 'HARRIS CO., TX', '(UNINCORPORATED AREAS)', 'community no . 4802878']
# None
# ['DEPARTMENT OF housing ANd URBAN DEVELOPMENT', 'Federal Irurancc Administration', 'FLOOD HAZaRd b0undary MAP H .01-02', '(O_HAp inder', 'CITY OF BELLAIRE, TX', '(HARRIS CO))', 'comnunity nO . 480289A']
# None
# ['DEPARTMENT Of housing And URBAN OEVELOPMENT ', 'Federal Insurance Administration', 'City   OF BELLAIRE , TX', 'HARR / S CO . )', 'MAP INDEX', '0', 'FIA FloOO HAZARO BOUNdARY MAPS', 'No h', '01 - 02', 'licre']
# None
# ['DEPARTMENT OF HOUSING AND URBAN DEVELOFMENT', 'Federal Insurance Administration', 'FLOOD Hazard BoUndary Map H . 01-02', 'MaP INDEX @,', 'City OF BUNKER KILL VILLAGE, TX', '(HARR |S Co,', 'community no. 480290A']
# None
# ['DEPARTMENT Of HOuSing And UrBAN DEVELOPMENT', 'Federal Insurance Administration', 'city  OF DEER PARK', '1', 'TX', 'HARRIS CO .', 'MAP imdex', 'C', 'FIA FloOO HAZARO BOUMOAAY MaPS', 'No H   01-06', 'licro']
# None
# ['DEPARTMENT OF HOUSing And URBAN OEVELOFMENT', 'Federal |rsurance Administration', 'FLOOD Hazard boundary MaP h . 01-02', 'Map index', 'CITY OF GALENA PARK, TX', '(HARRIS CO.)', 'community nO . 480293A', 'To']
# None
# ['DEPARTMENT OF Housing AND URBAN DEVELOpmeNt', '(Federal  Insurance Administration', 'ciy OF GALENA PARK,K T', '(HARRIS CD , )', 'MAP index', 'FIA Flood Hazard Bounoary Maps', 'No m', '01 02']
# None
# ['DEPARTMENT 0F Housing AND URBAN DEVELOFMENT', 'Federal Insurance Administration', 'FLOOd HAzard Boundary Map H . 01', 'Map INDEX', 'CITY OF HILSHIRE VILLAGE, TX', '(HARRIS COJ)', 'Community nO . 480295A', 'To']
# None
# ['DEPARTMENT Of Housing And URBAN DEVELOFMENT', 'Federal Insurance Administration', 'FLOOD HAZard BOURDARY Map K . 01.174', 'MaP INDEX', 'CITY OF HOUSTon, TX', '(FORT BEND; HARRIS AND MONTGOMERY COS }', 'community n0. 480296A', 'Kto,']
# None
# ['DEPARTMENT Of housing And URBAN dEvelopmenT:', 'Federsl Imsursnce Adminstition', 'Flood Hazard Boiindary Map h . 01+-03', 'Map IndEX', 'OF   HUMBLE', '(HARRIS CO.', 'commumity no . 480297.4', 'Kenbud', 'Jic', 'ise']
# None
# ['DEPARTMENT OF Housing ANd URBAN DEVELOFMERT', 'Fedorel Insuronce Administrition_', 'Flood HAZARD BOUNDary MAP H ~ 01.02', "MaP 'InDEx:", 'T', 'City OF HUNTERS CREEK VILLAGE, TX', '(HARRIS CO:)', 'conmumity nO : 480298A:']
# None
# ['DEPARTMENT OF Housing ANd URBAN DEVELOPMENT;', "Federsl lasuronce Administration'", 'city QF JACInTO CiTY , TX', '(HARRI S CO _', 'MAP indeX', '0', 'FIA FLoOO HazARO BOUnOARY MaPS', 'No. # 01', '480299', 'f', 'C']
# None
# ['OEPARTMENT Of Housing AND \'UrBan"\' QEVELOPMENT]', 'Federal Insurance  Administration', "CITY 0F 'J ERSEY  VILLAGE , TX", 'HARRI"S \'CO', 'U) " MAP INDEX', 'FIA FloOO HAZARO BOUNDARY MAPS', 'No H', '01-04', 'AICI']
# None
# ['DEPARTMENT OF Housing And URBAN DEVELOFRENT:', 'Federal !nsurance Adixetictration', 'FLOOD Hazard Boundary MaP H .   01-04', 'Map INDEX', 'Q', 'Ccity OF KATI , TX', '(HARRIS, FORT BEND AND WALLER COS:)', 'community n0.  480301A']
# None
# ["DEPARTMENT Of 'housing Ano: URBAN deveiopment ", 'Federal Insurance; Administiation', 'CITY QFLMISSOURI ChTY , TX', '(HARRI S   CO:.', 'MAP INDEX', 'FIA FloOO HAZARD BOUNOARY_ MAPS', 'No. H   01-09']
# None
# ['deparTMERT Of HquSinG And UrbaN deveLOEMENT', 'Fodenl Icsuioned Adminisuetia', 'FLOOD HAzard BQUndary Map H . 01', 'Map INdEx', 'ciTY) OF MORGANS   Po inT , TX:', '(HARRIS CO,', 'comminity nd. 480305a:', 'S']
# None
# ['DEPARTMENT OF HOuSing ANd URBAN DEVELOPMENT', 'Federal |nsurance Administration', 'FLOOD HAZARD BOUNDARY MAP H . 01-22', 'CHap Index:', "@F PASADENA'", '(HARR/S CO.', 'community no. 48.03074', 'TC', '(Sei']
# None
# ['DEPARTMENT OF housiNG ANd UrbAN devELOFmEnt', 'Fcderl Iaurance Administration', 'FLOOD HAZard BOUNDARY MAP H ` 01-22', 'FLOOD insurance RATE MAp | . 01-22', 'Map IndeX', 'Ci TY   OFdPASADENA , TX', '(HARR |S CO , )', 'community nO, 480307C', '3']
# None
# ["OEPARTMENT Of Housing And URBAN 'OEVELOPMENT", 'Fedetal Insurance Administration', 'city OF PinEY Point VILLAGE, TX', '(HARRIS Co:)', 'MAP indeX', 'FIA FLoOO HAZARO BOUNDARY MAPS', 'No H   01-02', '4803o2']
# None
# ['OEPARTMENT OF HOuSing ANd UrBAN CEVELOFMENt', 'Fedoral  Isucance Administratiaa', 'city OFSOUTH HOUSTON , TX', 'O " (HarRIS5CO', 'MAP index', 'FIA Flooo HAZARD_BOUNOAR} MAPS', 'No. H   01-02']
# None
# ['DEPARTMENT OF HouSing ANd URBAN DEVELOPMENT', 'Federal Insucence Administration', 'FLOOd hazard BOUndAry MAp H  01', 'Map IndeX', 'U0', 'CITY OF SPRING VALLEY, TX', '(HARRIS CO )', 'comm Unity nO . 4803134', 'To']
# None
# ['DEpARTMENT Of Housing And URBAN DEVELOPMENt', 'Federel ksuronce Administration', 'city_Of TOMBALL, TX', '(HARRIS#CO', '0', 'MAP IMDEX', 'fVA Flooo Hnzard Oounoary MapS', 'No. H   0|-05']
# [datetime.datetime(1970, 9, 25, 0, 0), datetime.datetime(1971, 8, 13, 0, 0)]
# None
# ['DEPARTMENT OF HOUsing AND URBAN DEVELOPMENT', 'Federal Insurance Administration', 'FLOod hazaRd BOUNDARY MAP H . 01 - 05', 'FLood INSURANCE RATE Map | . 01- 05', 'KAP IMDEX', 'OF" KnGSVLLE', 'TXa', '(KLEBERG', '6', 'Commuitya A0 . 4804244', 'stc']
# None
# ['DEPARTMENT OF HOUSing AND URBAN DEVELOPMENT', 'Federal Insurance Administration', 'FLOOD HAzARd BOUNDARY MAP H . 0h-05', 'FLOOD IKSURANCE RATE MAP | . 01-05', 'MAP INDEX', 'Ci Ty OF KingsviLLE, TX', '(XLEBERG CO . )', 'CohkUhity Ho . 4804248', 'Kto']
# [datetime.datetime(1970, 10, 9, 0, 0), datetime.datetime(1971, 2, 26, 0, 0)]
# None
# ['DEPARTMENT OF Housing ANd URBAN dEVELOFMENT', 'Fedetal Insurtince Administration', 'FLOOd hazaro BoundAry Map h . 01', 'Map IndEX', 'CITY OF WALLER; TX', '(WALLER AND HARRIS', "'Cos:)", 'community nO. 4806414', 'to']
# None
# ['OEPARTMENT OF kousing AND URBAN OEVELOPMENT', 'Federal  Insufance  Administration', 'C/TY OF LYTLE, TX', '(atascosa & BEXAR COS', 'MAP indeX', 'FIA Flooo HAZARD BOUNDARY MAPS', 'No. h', '0 1-02']
# None
# ['DEPARTMENT OF HOUSING Aho URBAN DEVELOFMENT', 'Foderl Insurance Administration', 'FLOOD HAZard BOUNDARy MAP H - 01-02', 'Omap IndEX', 'OF ELMENDORF , TX', '(BEXAR CO:)', 'chmminity nO. 480710', '5city']
# None
# ['DEPARTMENT OF Housing AND URBAN DEVELOPMENT', 'Federal Insursnce Administaation', 'city OF BALCONES HETGHTS , IX', 'BEXAR cQ', 'MAP INDEX', 'FIA FLOOD HAZARO BOUNDARY MAPS', 'No H', '01', 'ICr']
# None
# ['DEPARTMENT OF HOUSinG AND URBAN DEVELOPMENT', 'Federal  lnsurance Administration', 'cFTY OF CHINA "GROVE ,eTX', '(BEXAR CO', 'MAP INdEX', 'FIA FLOOO HAZARO BOUNDARY MAPS', 'No. H   01-02']
# None
# ['DEPARTMENT OF HOUSinG ANd URBAN DEVELOFMENT', 'Federal Insurance Administration', 'FLOOD HAZard BOUNDARY MAP H ` 01-19', 'FLOOD UNSURAncE RATE  MAP | . 01-19', 'MaP InDEX', '0 ~cty QF BAYTOWN, TX', 'HARRIS CO . )', 'community nO. 485456A']
# None
# ['depaRTMEN 0f Housi6 Nno UrBAN DeVelopMemtt', 'Fadarol hasent Adntnisutton', 'city OF EL LaGo; T', '(HARRI $ CO', 'FIA Flood Hazaao BOUNoNxy Maps', 'No. m  01', 'FVAFlood InsuaaHCr Rate Maps', 'Vo [# 01']
# None
# ['OEPARTMENT Of huusing And URBAN DEVELOPMENT', 'Federal  Insurance  Administration', 'FRIEN OSWO 00, TXa', '0', 'MAP INdEX', 'FIA FLOOO KAZARO BOUNDARY MAPS', 'No 4 # 02', 'FIA floOd INSURANCE RATE MAPS', 'Vee NVu eeeue   02', 'Atea elgible Ior Federally assisted Ilood insurance', 'CORPORATE limits']
# None
# ['DEPARTMENT OF HOUSing ANd Urban DEVELOPMENT', 'Federal Insurance Administration', 'FLOOD HAZARD BOUNDARY MAP H.01-06', 'FLOOd INSURANCE RATE MAP | 301-06', 'map INdEX', 'city OF FRIENDSWOOD , TX', '(GALVESTON CO.)', '0mmunity nO . 485468B']
# None
# ['DEPARTMENT 0F Housing And URBAW DEVELOPMENT', 'Federal Insurance Administration', 'FLOOD HAZARD BOUNDARY MAP H + 0', 'FLOOD INSURANCE RATE Map | . 01-17', 'MaP INDEX', 'city OF GALVESTON , TX', 'GALVESTON CO , )', '€0mmunity nO . 485469B']
# None
# ['DIPARTMINT d HuusinG ANo?UNBAN', 'Fedetat Insetance', 'GANE', 'TNCERRURA', 'FiA Flod #aar0 BOUNOAAY: MAc', 'Nc', 'Enuctive Date', 'having Aeecha (loce baiists', "'ZONE A11a17i", 'Wooo InsuraNcE Rate Map', '{nectivc : Dai', 'Aiea elgibit Jot<Eedetaly', 'ainsted  Honae Wonufance , NANCURPLRAEGAREAS', '52', 'Area', 'VA;', 'Ao']
# None
# ['DEPARTMENT Of HOusing AND URBAN deveLopENT', 'Federal Insurance Administratian', 'FLoOd hazard BOundary MaP H  01-57', 'FLoOd insurance Rate MaP | - 01-57', 'Map-INDEX', 'GALVESTON €O, TX', 'UNINCORPORATED PREA)', 'community no,  485470B']
# None
# ['WtCICd', 'DEPARTMENT OF HOusing ANd URBAN DEVELOFMENT', 'Federal Insurance Administration', 'FLOOD HAZArd BOUNDARY MAp H - 01-06', 'FLoOd INSURANCE RATE MAP | . 0 1-06', 'MaP INDEX', 'City OF LA MARQUE, TX', '(GALVESTON  CO , )', 'community nO.   485486A']
# None
# ['DEPARTMENT QF HousiG AND URBAN QeveloPMENT', 'Federel hurtnco Ndminisuttien', 'ITY 0F LA PORTE ,TX', 'HARRIS CO', 'Fia Flood HNzaro BoundaRY MapS', 'No. #   01- 08', 'FLA Flooo Insurance RATE MAPS', 'Noal 00 1 - 08']
# [datetime.datetime(2008, 4, 1, 0, 0)]
# [datetime.datetime(1970, 8, 27, 0, 0)]
# None
# ['DEPARTMENT OF HOUSing AND URBAN DEVELOPMENT', 'Federal Insurance Administration', 'FLOOD hazard BOUNDARY MAP H `4701115', 'FLOOD INSURANCE RATE  MAP | . 01-15', 'MaP IKDEX', 'City 0F LEAGUE CITY, TX', 'GALVESTON C0 . )', 'community no.  4854884']
# None
# ['DEPARTMENT Of Housing Ano URBAN DEVELOpMENt', 'Federal  bsuranco Administation', 'C| TY OF NASSAU BAY , TX', '(HARRIS CO . )', 'FIA Flooo HAZARO BOUNOARY MAPS', 'No. H   01', 'FIA Flooo INSURANCE RATE MAPS', 'No: [ 01']
# None
# ['DEPARTMENT OF HOuSing ANd URBAN DEVELOPMENT', 'Federal Insurance Admninistration', 'FLOOD HAZARD BOUNDARY MAP H', 'FLOOD INSURancE RATE MaP', 'Map index', 'CTY OF NASSAU BAY, TX', '(HARRIS CO', 'cokmunity no.  485491c']
# None
# ['DEPARTMENT 0f Housikg And URBAN devELOFMENT', 'Fodcrtl fncnnce Adminlttntion', 'FLOOD HAZARd BOUndaRy MaP H . 01', 'FLood insurance Rate Map | . 01', 'Map INdEX', 'CITY OF NASSAi BAY , TX', '(HARRIS CO . )', 'community no . 485491D']
# None
# ['DEPARTMENT 0F Housing And URBAN DEVELOPMENT', 'Federal |nsurance Administration', 'FLOOD HAZARD BOUNDARY Maph . 01 . 02', 'FLOOD INSURAncE RATE MAP | . 01 . 02', 'Map IKDEX', 'VIlLace 0F TAYLOR LAKE, TX', '(harris C0. )', 'c0 mmunityu No, 4855130', 'Co']
# None
# ['DEPARTMENT OF HGuSing AND URBAN DEVELOPMENT', 'Federal Insurance Administration', 'WEBSTER; TX', '0', 'MAP INDEX', 'FIA FLOOO HAZARO BOUNDARY MAPS', 'No. H # W08-14', 'FIA FloOo INSURANCE RATE MAPS', 'No; [ V Vubeede ` 08-14', 'Arca elgible Io;  Federally assisted  (lood Insurance', 'CORPORATE LimitS', 'Ol']
# None
# ['DEPARTMENT Of HOusing And URBAN developmEnt', 'Federal Insurance Administration', 'FloOd HAZARd BOUndary MAP H . 0.', 'Map indeX', 'CITY OF SOMERSET , TX', '(BEXAR CO.)', 'communitt 40 . 481264A']
# None
# ['DEPARTMEMT OF HoUSing AND URBAN DEVELOPMENT', 'Federal Insurance Administration', 'CLEAR LAKE SHORES, TX', 'FIA Flooo HAZARD BOUNDARY MAP', 'No. H 03', 'Effective Date: See Note', 'Area having special (lood hazards ZONES', 'FIA FLOOD INSURANCE RATE MAPL', 'Na In Wubeaa  03', 'Elective Date:  JULY 48,1971', 'Area   eligiblee for  Federally', 'assisled  flood VInsurance . CORPORATE LImITS', '5609', 'rom', 'Icie']
# [datetime.datetime(1970, 8, 14, 0, 0), datetime.datetime(1971, 7, 2, 0, 0)]
# [datetime.datetime(1970, 8, 27, 0, 0), datetime.datetime(1970, 11, 13, 0, 0)]

# %%
k
# Out:
# '480035IND0_0490.jpg'

# %%
out_dir = r"D:\RECTDNN\TNNN\images2\\"

# key = "48201"

smart_dict = {}

unsureCounter = 0
try:
    reader
except:
    reader = easyocr.Reader(['en']) 

for i, (k, v) in tqdm(enumerate(gen_dict.items()), total=len(gen_dict.items())):
    key = findIndexKey(k)

    dates_found, text_found = extractDate(v['legend'][0]['data'], filter_values=['revised', 'effective'])
    affine   = Affine(*v["output_transform"].flatten()[:6])
    
    for ii, (kk, vv) in tqdm(enumerate(v['tile'].items()), total=len(v['tile'].items()), leave=False):
        try:
            image = prepImageForReading(vv['data'])

            texts = reader.readtext(cv2.cvtColor(resize_image(image, size=1024), cv2.COLOR_GRAY2BGR), detail=0, width_ths=50)
            
            texts = [a for a in texts if len(a) >= len(key)]
            if not len(texts) == 0:
                text, val = process.extractOne(key, texts)
            else: 
                val = 0
            if val < 60:
                text = f"Unsure{unsureCounter}"
                unsureCounter = unsureCounter + 1
            else:
                # text= text.split(" ")[0]
                text = re.sub('[^A-Za-z0-9]+', '', text)
                text = re.sub(f'^.*?{key}', key, text)
                text = text.upper()
                text = re.sub('O', '0', text)
                text = re.sub('T', '1', text)
                text = re.sub('Q', '0', text)
                text = re.sub('Z', '7', text)
                if text[-1] == '1':
                    text = text[-1]


                score, s1_start, s1_end, s2_start, s2_end = fuzz.partial_ratio_alignment(text, key)

                text = key + text[s1_end:]
                
            # CALCULATE COORDS FROM AFFINE 
            bbox = vv['bbox']
            left, bottom = affine * (bbox[0], bbox[1])
            right, top   = affine * (bbox[2], bbox[3])
            
            if text[-1].isalpha():
                tilename = text[:-1]
                inner_key = text[-1]
            else:
                tilename = text
                inner_key = 0
            
            currKeyCheck = smart_dict.get(tilename, None)
            if currKeyCheck is None:
                smart_dict[tilename] = {}

            currInnerKeyCheck = smart_dict[tilename].get(inner_key, None)
            if currInnerKeyCheck is None:
                smart_dict[tilename][inner_key] = {}
                smart_dict[tilename][inner_key]['coords'] = []
                smart_dict[tilename][inner_key]['indexes'] = []
                smart_dict[tilename][inner_key]['pix'] = []
                smart_dict[tilename][inner_key]['dates'] = []
            
            smart_dict[tilename][inner_key]['pix'].append(bbox)
            smart_dict[tilename][inner_key]['coords'].append(np.array([left, bottom, right, top]))
            smart_dict[tilename][inner_key]['indexes'].append(k)
            smart_dict[tilename][inner_key]['dates'].append(dates_found[0])
        except Exception:
            print(traceback.format_exc())
            continue

    try:
        with open("save.p", "wb" ) as f:
            pickle.dump(smart_dict, f)
    except Exception:
        print(traceback.format_exc())
        continue


'''
new_tile_idx = 0
out_fn = os.path.join(out_dir, text) + ".png"
if os.path.exists(out_fn):
    while os.path.exists(out_fn):
        extension = f"_{new_tile_idx}.png"
        out_fn = os.path.join(out_dir, text) + extension
        new_tile_idx = new_tile_idx + 1



# plt.imsave(out_fn, image, cmap='Greys_r')'''
# Out:
#   0%|          | 0/171 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]

# %%
smart_dict
# Out:
# {'480035': {0: {'coords': [array([ -1.098e+07,  3.4399e+06, -1.0965e+07,  3.4242e+06]),
#     array([-1.0982e+07,  3.4727e+06, -1.0967e+07,  3.4568e+06]),
#     array([-1.0965e+07,  3.4244e+06,  -1.095e+07,  3.4088e+06]),
#     array([-1.0968e+07,  3.4734e+06, -1.0953e+07,  3.4576e+06]),
#     array([-1.0951e+07,  3.4252e+06, -1.0936e+07,  3.4097e+06]),
#     array([ -1.098e+07,  3.4388e+06, -1.0965e+07,  3.4227e+06]),
#     array([-1.0982e+07,  3.4721e+06, -1.0967e+07,   3.456e+06]),
#     array([-1.0968e+07,  3.4728e+06, -1.0953e+07,  3.4568e+06]),
#     array([-1.0981e+07,  3.4725e+06, -1.0966e+07,  3.4565e+06])],
#    'indexes': ['480035IND0_0490.jpg',
#     '480035IND0_0490.jpg',
#     '480035IND0_0490.jpg',
#     '480035IND0_0490.jpg',
#     '480035IND0_0490.jpg',
#     '480035IND0_0789.jpg',
#     '480035IND0_0789.jpg',
#     '480035IND0_0789.jpg',
#     '480035IND0_0990.jpg'],
#    'pix': [array([     970.77,      1510.4,      1377.3,      1972.4]),
#     array([     973.61,      597.52,      1379.3,      1063.6]),
#     array([     1364.4,      1967.7,      1776.2,      2425.5]),
#     array([     1373.7,      601.27,        1780,      1065.5]),
#     array([     1766.1,        1967,      2172.8,      2425.2]),
#     array([     961.51,        1516,      1369.3,      1981.6]),
#     array([     958.35,      599.29,      1369.7,      1066.7]),
#     array([     1362.7,      601.54,      1771.5,      1066.4]),
#     array([     968.59,      599.88,      1372.9,      1065.2])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0),
#     datetime.datetime(1990, 9, 28, 0, 0)]}},
#  '4800350625': {'B': {'coords': [array([-1.0978e+07,  3.4074e+06, -1.0963e+07,  3.3914e+06]),
#     array([-1.0978e+07,  3.4058e+06, -1.0963e+07,  3.3895e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     970.19,      2418.7,      1371.1,      2888.1]),
#     array([     964.85,      2426.2,      1367.4,      2897.7])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350240': {'B': {'coords': [array([-1.0952e+07,  3.4493e+06, -1.0945e+07,  3.4418e+06]),
#     array([-1.0952e+07,  3.4488e+06, -1.0945e+07,  3.4411e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0990.jpg'],
#    'pix': [array([     1770.4,        1296,      1975.7,        1519]),
#     array([     1766.4,      1295.8,      1971.8,      1520.4])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1990, 9, 28, 0, 0)]}},
#  '48003502750': {0: {'coords': [array([-1.0939e+07,  3.4586e+06, -1.0924e+07,  3.4429e+06]),
#     array([-1.0939e+07,  3.4577e+06, -1.0924e+07,  3.4419e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     2164.8,        1060,      2570.9,        1523]),
#     array([       2158,      1064.3,      2562.2,      1524.3])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350305': {'C': {'coords': [array([-1.0994e+07,  3.4389e+06, -1.0986e+07,   3.431e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([     577.11,      1514.8,      773.73,      1747.8])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]},
#   'B': {'coords': [array([-1.0994e+07,  3.4378e+06, -1.0986e+07,  3.4297e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([        568,      1521.6,      765.91,        1756])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350310': {'D': {'coords': [array([-1.0987e+07,  3.4393e+06, -1.0979e+07,  3.4314e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([     771.21,      1514.9,      979.21,      1748.3])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]},
#   0: {'coords': [array([-1.0987e+07,  3.4382e+06, -1.0979e+07,  3.4301e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([     761.81,        1521,      970.67,      1755.5])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350195': {'C': {'coords': [array([-1.0974e+07,  3.4482e+06, -1.0966e+07,  3.4405e+06]),
#     array([-1.0973e+07,  3.4473e+06, -1.0966e+07,  3.4394e+06]),
#     array([-1.0973e+07,  3.4479e+06, -1.0966e+07,  3.4401e+06])],
#    'indexes': ['480035IND0_0490.jpg',
#     '480035IND0_0789.jpg',
#     '480035IND0_0990.jpg'],
#    'pix': [array([       1169,      1291.6,      1374.4,        1517]),
#     array([     1161.2,      1293.9,      1367.3,      1523.1]),
#     array([     1163.7,      1293.5,      1370.5,      1519.4])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0),
#     datetime.datetime(1990, 9, 28, 0, 0)]}},
#  '4800350295': {'B': {'coords': [array([   -1.1e+07,  3.4302e+06, -1.0993e+07,  3.4226e+06]),
#     array([   -1.1e+07,   3.429e+06, -1.0993e+07,  3.4211e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     378.27,      1745.8,      579.16,      1970.2]),
#     array([     371.16,      1752.6,      571.61,      1979.8])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350170': {'D': {'coords': [array([-1.0987e+07,  3.4473e+06,  -1.098e+07,  3.4397e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([     771.57,      1292.4,      979.39,      1516.3])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]},
#   0: {'coords': [array([-1.0987e+07,  3.4463e+06,  -1.098e+07,  3.4386e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([     762.11,      1297.2,      971.36,      1522.4])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350315BS': {'S': {'coords': [array([-1.0993e+07,  3.4306e+06, -1.0986e+07,  3.4229e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([     575.98,      1746.2,      773.04,      1972.3])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]}},
#  '4800350285': {'B': {'coords': [array([-1.1001e+07,  3.4385e+06, -1.0993e+07,  3.4306e+06]),
#     array([   -1.1e+07,  3.4373e+06, -1.0993e+07,  3.4293e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     379.34,      1514.2,      580.44,      1747.9]),
#     array([     371.85,        1522,      570.94,      1755.7])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350495': {'B': {'coords': [array([-1.0972e+07,  3.4156e+06, -1.0964e+07,   3.408e+06]),
#     array([-1.0972e+07,  3.4141e+06, -1.0964e+07,  3.4063e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     1164.2,      2200.4,      1371.2,      2423.7]),
#     array([     1158.7,      2208.9,      1366.2,      2434.7])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350165': {'B': {'coords': [array([-1.0994e+07,  3.4469e+06, -1.0987e+07,  3.4393e+06]),
#     array([-1.0994e+07,  3.4459e+06, -1.0987e+07,  3.4382e+06]),
#     array([-1.0994e+07,  3.4469e+06, -1.0987e+07,  3.4392e+06])],
#    'indexes': ['480035IND0_0490.jpg',
#     '480035IND0_0789.jpg',
#     '480035IND0_0990.jpg'],
#    'pix': [array([     578.51,      1291.2,      775.17,      1515.4]),
#     array([     568.08,      1297.4,       765.8,      1522.3]),
#     array([     570.38,        1294,      769.18,      1518.8])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0),
#     datetime.datetime(1990, 9, 28, 0, 0)]}},
#  '4800350320': {'C': {'coords': [array([-1.0987e+07,   3.431e+06, -1.0979e+07,  3.4235e+06]),
#     array([-1.0986e+07,  3.4298e+06, -1.0979e+07,   3.422e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     770.03,        1747,      978.29,      1969.5]),
#     array([      761.6,      1753.2,       971.9,      1978.3])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350050': {0: {'coords': [array([-1.0996e+07,  3.4719e+06,  -1.098e+07,  3.4561e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([     577.99,      595.67,      984.98,      1060.3])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]},
#   'C': {'coords': [array([-1.0996e+07,  3.4712e+06,  -1.098e+07,  3.4552e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([     565.85,      600.19,       974.1,      1065.8])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350245': {0: {'coords': [array([-1.0945e+07,  3.4498e+06, -1.0938e+07,  3.4422e+06]),
#     array([-1.0946e+07,  3.4488e+06, -1.0938e+07,  3.4411e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     1972.7,      1295.8,      2171.4,      1518.8]),
#     array([     1963.7,      1298.7,      2162.7,      1522.7])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350380': {'C': {'coords': [array([-1.0952e+07,  3.4414e+06, -1.0944e+07,  3.4333e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([     1767.1,      1516.8,      1975.1,      1754.7])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]},
#   0: {'coords': [array([-1.0952e+07,  3.4403e+06, -1.0945e+07,   3.432e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([     1761.7,        1520,      1968.4,      1760.1])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350525': {'B': {'coords': [array([-1.0937e+07,  3.4261e+06, -1.0922e+07,  3.4105e+06]),
#     array([-1.0965e+07,   3.423e+06,  -1.095e+07,  3.4071e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([       2162,      1967.7,        2571,      2426.9]),
#     array([     1359.7,      1974.9,      1771.4,      2434.5])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '48003504480': {'B': {'coords': [array([-1.0979e+07,  3.4235e+06, -1.0972e+07,  3.4155e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([     973.21,      1967.8,      1167.5,      2204.2])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]}},
#  '4800350650': {'B': {'coords': [array([-1.0964e+07,  3.4082e+06, -1.0949e+07,  3.3922e+06]),
#     array([-1.0964e+07,  3.4065e+06, -1.0949e+07,  3.3903e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     1363.4,      2419.2,      1772.7,      2887.9]),
#     array([     1357.6,      2427.3,      1768.6,      2897.1])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350190': {'B': {'coords': [array([ -1.098e+07,  3.4477e+06, -1.0973e+07,  3.4401e+06]),
#     array([ -1.098e+07,  3.4467e+06, -1.0973e+07,   3.439e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     976.17,      1292.6,      1172.8,      1516.2]),
#     array([     967.27,      1297.4,        1165,      1522.1])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350395': {'B': {'coords': [array([-1.0944e+07,  3.4334e+06, -1.0937e+07,   3.426e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([     1971.6,      1750.7,      2169.6,      1970.3])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]}},
#  '4800350485': {'B': {'coords': [array([-1.0972e+07,  3.4239e+06, -1.0964e+07,  3.4159e+06]),
#     array([-1.0972e+07,  3.4225e+06, -1.0965e+07,  3.4143e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     1163.6,      1967.7,      1372.3,      2203.5]),
#     array([     1156.9,      1974.8,      1366.6,      2214.5])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350600': {'B': {'coords': [array([-1.0992e+07,  3.4064e+06, -1.0977e+07,  3.3905e+06]),
#     array([-1.0992e+07,  3.4048e+06, -1.0977e+07,  3.3887e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     572.62,      2420.3,       976.8,      2889.7]),
#     array([     567.52,      2428.6,      973.25,      2897.2])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350150': {'B': {'coords': [array([-1.1009e+07,  3.4546e+06, -1.0994e+07,  3.4389e+06]),
#     array([-1.1008e+07,  3.4537e+06, -1.0993e+07,  3.4376e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([      179.8,      1053.7,      584.37,      1514.6]),
#     array([     168.48,      1059.3,      575.62,        1526])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350425': {'B': {'coords': [array([-1.0938e+07,  3.4423e+06, -1.0923e+07,  3.4267e+06]),
#     array([-1.0939e+07,  3.4413e+06, -1.0924e+07,  3.4254e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([       2161,      1514.7,        2571,      1975.7]),
#     array([     2155.9,      1516.9,      2562.5,      1978.7])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350785': {0: {'coords': [array([-1.0974e+07,  3.4565e+06, -1.0966e+07,  3.4485e+06]),
#     array([-1.0974e+07,  3.4562e+06, -1.0966e+07,  3.4482e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0990.jpg'],
#    'pix': [array([     1168.6,      1059.6,      1375.7,      1294.1]),
#     array([     1161.7,      1061.4,        1371,      1296.2])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1990, 9, 28, 0, 0)]}},
#  '4800350390': {'B': {'coords': [array([-1.0952e+07,   3.433e+06, -1.0944e+07,  3.4255e+06]),
#     array([-1.0952e+07,  3.4321e+06, -1.0944e+07,  3.4241e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     1768.9,      1751.6,      1975.2,      1972.1]),
#     array([     1762.6,      1746.8,      1968.2,        1978])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350180': {'C': {'coords': [array([-1.0981e+07,  3.4561e+06, -1.0973e+07,  3.4481e+06]),
#     array([-1.0981e+07,  3.4552e+06, -1.0973e+07,  3.4471e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     977.02,      1059.3,      1173.8,      1293.8]),
#     array([     967.08,      1064.2,        1164,      1299.4])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350490': {'B': {'coords': [array([-1.0979e+07,  3.4152e+06, -1.0971e+07,  3.4076e+06]),
#     array([-1.0978e+07,  3.4136e+06, -1.0971e+07,  3.4059e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     972.29,      2200.2,      1168.2,      2423.4]),
#     array([     966.94,      2209.2,      1161.9,      2433.9])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350025': {'B': {'coords': [array([ -1.101e+07,  3.4711e+06, -1.0994e+07,  3.4552e+06]),
#     array([-1.1009e+07,  3.4703e+06, -1.0994e+07,  3.4543e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     183.14,      594.88,      586.26,      1060.1]),
#     array([     169.28,      601.22,       577.4,      1066.8])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350225': {0: {'coords': [array([-1.0967e+07,  3.4569e+06, -1.0952e+07,  3.4413e+06]),
#     array([-1.0967e+07,  3.4561e+06, -1.0952e+07,  3.4402e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([       1367,      1059.3,      1779.6,      1519.6]),
#     array([     1360.6,      1061.6,      1770.3,      1524.5])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350475BLEL': {'N': {'coords': [array([-1.0993e+07,  3.4227e+06, -1.0978e+07,  3.4072e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([      569.7,      1966.4,      978.88,      2423.1])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]},
#   'M': {'coords': [array([-1.0993e+07,  3.4164e+06, -1.0978e+07,  3.4072e+06]),
#     array([-1.0993e+07,  3.4213e+06, -1.0978e+07,  3.4055e+06]),
#     array([-1.0992e+07,  3.4149e+06, -1.0978e+07,  3.4055e+06])],
#    'indexes': ['480035IND0_0490.jpg',
#     '480035IND0_0789.jpg',
#     '480035IND0_0789.jpg'],
#    'pix': [array([     574.66,      2142.3,      974.38,      2423.3]),
#     array([     563.99,      1974.1,      973.17,      2434.1]),
#     array([     569.89,      2150.4,      965.27,      2433.8])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350675': {'B': {'coords': [array([ -1.095e+07,   3.409e+06, -1.0935e+07,  3.3931e+06]),
#     array([ -1.095e+07,  3.4074e+06, -1.0936e+07,  3.3912e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     1765.7,      2420.1,      2170.6,      2888.9]),
#     array([     1760.4,      2427.7,      2163.8,      2896.5])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350375': {'B': {'coords': [array([-1.0966e+07,  3.4407e+06, -1.0951e+07,  3.4251e+06]),
#     array([-1.0965e+07,   3.432e+06, -1.0951e+07,  3.4251e+06]),
#     array([-1.0966e+07,  3.4395e+06, -1.0951e+07,  3.4237e+06])],
#    'indexes': ['480035IND0_0490.jpg',
#     '480035IND0_0490.jpg',
#     '480035IND0_0789.jpg'],
#    'pix': [array([     1368.6,      1513.5,        1777,        1973]),
#     array([     1372.9,        1754,      1771.7,      1970.6]),
#     array([     1359.5,      1519.8,      1770.9,      1978.7])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350450': {'B': {'coords': [array([-1.1007e+07,  3.4219e+06, -1.0992e+07,  3.4063e+06]),
#     array([-1.1007e+07,  3.4219e+06, -1.0998e+07,  3.4059e+06]),
#     array([-1.1007e+07,  3.4204e+06, -1.0991e+07,  3.4046e+06]),
#     array([-1.1007e+07,  3.4204e+06, -1.0997e+07,  3.4042e+06])],
#    'indexes': ['480035IND0_0490.jpg',
#     '480035IND0_0490.jpg',
#     '480035IND0_0789.jpg',
#     '480035IND0_0789.jpg'],
#    'pix': [array([     177.05,      1964.6,      583.42,      2423.9]),
#     array([     175.57,      1966.5,      409.29,      2425.3]),
#     array([     166.88,      1975.3,      576.18,      2436.2]),
#     array([     168.41,      1977.2,      402.59,      2435.2])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350125': {'C': {'coords': [array([-1.0954e+07,  3.4742e+06, -1.0939e+07,  3.4584e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([     1762.2,      600.71,      2174.3,      1065.9])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]},
#   0: {'coords': [array([-1.0954e+07,  3.4737e+06, -1.0939e+07,  3.4576e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([       1762,      601.32,      2165.5,        1067])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350155': {'B': {'coords': [array([-1.0995e+07,  3.4553e+06, -1.0987e+07,  3.4473e+06]),
#     array([-1.0994e+07,  3.4544e+06, -1.0987e+07,  3.4462e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     581.32,      1058.4,      781.44,      1294.1]),
#     array([     569.15,      1064.5,      766.36,      1300.2])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350160': {'B': {'coords': [array([-1.0988e+07,  3.4557e+06,  -1.098e+07,  3.4477e+06]),
#     array([-1.0988e+07,  3.4547e+06,  -1.098e+07,  3.4466e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     769.16,      1059.3,      981.63,      1293.4]),
#     array([     758.59,      1064.9,      971.55,      1300.6])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350065': {'B': {'coords': [array([-1.0981e+07,  3.4643e+06, -1.0974e+07,  3.4565e+06]),
#     array([-1.0981e+07,  3.4636e+06, -1.0974e+07,  3.4556e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     977.38,      830.04,      1171.9,      1060.4]),
#     array([     967.19,      833.29,      1163.9,      1064.8])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '48003502500': {0: {'coords': [array([-1.0953e+07,  3.4577e+06, -1.0938e+07,    3.45e+06]),
#     array([-1.0953e+07,  3.4569e+06, -1.0939e+07,  3.4491e+06])],
#    'indexes': ['480035IND0_0490.jpg', '480035IND0_0789.jpg'],
#    'pix': [array([     1772.2,      1062.3,      2173.4,      1299.6]),
#     array([     1764.2,      1063.9,      2164.4,      1301.5])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0),
#     datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350385B': {'I': {'coords': [array([-1.0945e+07,  3.4418e+06, -1.0937e+07,  3.4337e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([       1972,      1517.8,      2170.8,        1755])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]}},
#  'Unsure0': {0: {'coords': [array([-1.0999e+07,  3.4223e+06, -1.0992e+07,  3.4153e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([     404.68,      1967.9,      577.98,      2173.4])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]}},
#  'Unsure1': {0: {'coords': [array([-1.0998e+07,  3.4155e+06, -1.0992e+07,  3.4065e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([     405.64,      2158.4,      577.15,      2420.4])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]}},
#  'Unsure2': {0: {'coords': [array([ -1.094e+07,  3.4745e+06, -1.0925e+07,  3.4592e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([     2169.9,      617.65,      2571.3,      1068.5])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]}},
#  'Unsure3': {0: {'coords': [array([-1.0953e+07,  3.4577e+06, -1.0945e+07,  3.4497e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([     1772.2,      1063.6,      1978.7,      1297.9])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]}},
#  'Unsure4': {0: {'coords': [array([-1.0966e+07,  3.4406e+06, -1.0951e+07,  3.4324e+06])],
#    'indexes': ['480035IND0_0490.jpg'],
#    'pix': [array([     1375.2,      1515.4,      1773.7,      1767.5])],
#    'dates': [datetime.datetime(1990, 4, 2, 0, 0)]}},
#  '480035240': {'B': {'coords': [array([-1.0953e+07,  3.4484e+06, -1.0945e+07,  3.4406e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([     1762.5,      1297.3,      1969.5,      1523.1])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350185': {0: {'coords': [array([-1.0974e+07,  3.4556e+06, -1.0966e+07,  3.4475e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([     1159.1,      1064.6,      1367.4,      1300.9])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350315': {'B': {'coords': [array([-1.0993e+07,  3.4294e+06, -1.0986e+07,  3.4214e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([     567.97,      1753.2,      767.54,      1982.8])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350480': {'B': {'coords': [array([-1.0979e+07,  3.4221e+06, -1.0972e+07,  3.4138e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([     967.33,      1974.9,      1162.8,      2215.1])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350575': {'B': {'coords': [array([-1.0938e+07,  3.4247e+06, -1.0923e+07,  3.4088e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([       2155,      1972.2,      2562.6,      2435.1])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350550B': {'L': {'coords': [array([-1.0951e+07,  3.4238e+06, -1.0936e+07,   3.408e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([     1760.8,      1974.1,        2166,      2435.2])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350385': {'B': {'coords': [array([-1.0945e+07,   3.433e+06, -1.0937e+07,  3.4246e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([     1963.7,        1733,        2162,      1976.2])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  'Unsure5': {0: {'coords': [array([-1.0945e+07,  3.4407e+06, -1.0938e+07,  3.4335e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([     1963.6,      1521.1,      2162.5,      1730.3])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  'Unsure6': {0: {'coords': [array([-1.0999e+07,  3.4209e+06, -1.0992e+07,  3.4142e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([     396.34,      1977.2,      569.93,      2169.6])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  'Unsure7': {0: {'coords': [array([ -1.094e+07,  3.4739e+06, -1.0926e+07,  3.4584e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([     2160.5,      618.73,      2546.1,      1068.1])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  'Unsure8': {0: {'coords': [array([-1.0966e+07,  3.4395e+06, -1.0952e+07,  3.4307e+06])],
#    'indexes': ['480035IND0_0789.jpg'],
#    'pix': [array([     1364.3,      1519.9,      1765.9,      1784.7])],
#    'dates': [datetime.datetime(1989, 7, 17, 0, 0)]}},
#  '4800350350': {'B': {'coords': [array([ -1.098e+07,  3.4397e+06, -1.0965e+07,  3.4238e+06])],
#    'indexes': ['480035IND0_0990.jpg'],
#    'pix': [array([     965.39,      1513.8,      1371.6,      1974.9])],
#    'dates': [datetime.datetime(1990, 9, 28, 0, 0)]}}}

# %%
"""
SNIPPET BELOW SHOWS GAUSSIAN BLUR MAY BE BENEFICIAL
key = "48201"
for i in range(10, 50):
    myimage = cv2.imread(r"D:\RECTDNN\TNNN\images1\Unsure6" + str(i) + ".png")
    test = cv2.GaussianBlur(cv2.cvtColor(resize_image(myimage, size=1024), cv2.COLOR_GRAY2BGR), (5,5), 1, 1)
    texts = reader.readtext(test, detail=0, width_ths=50)
    texts = [a for a in texts if len(a) >= len(key)]
    print(texts)
    if not len(texts) == 0:
        text, val = process.extractOne(key, texts)
    else: 
        val = 0
    if val < 60:
        text = f"Unsure"
        unsureCounter = unsureCounter + 1
    else:
        # text= text.split(" ")[0]
        text = re.sub('[^A-Za-z0-9]+', '', text)
        text = re.sub(f'^.*?{key}', key, text)
        text = text.upper()
        text = re.sub('O', '0', text)
        text = re.sub('T', '1', text)
        text = re.sub('Q', '0', text)
        text = re.sub('Z', '7', text)

        score, s1_start, s1_end, s2_start, s2_end = fuzz.partial_ratio_alignment(text, key)

        text = key + text[s1_end:]
    print(text)

"""
