# %%
import requests

# Base URL pattern with a placeholder for the integer
base_url = "https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_{:02d}_place.zip"  # Replace with your base URL
savedir  = r"C:\Users\fhacesga\OneDrive - University Of Houston\AAA_RECTDNN\data\ReferenceDatasets\Places"
# Loop through integers from 1 to 100
for i in range(1, 101):
    # Construct the URL by formatting the integer into the base URL
    url = base_url.format(i)

    try:
        # Send an HTTP GET request to the URL
        response = requests.get(url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Save the response content to a file with a filename based on the integer
            filename = f"{i}.zip"  # You can change the filename format
            with open(f"{savedir}/{filename}", "wb") as file:
                file.write(response.content)
            print(f"Saved {filename}")
        else:
            print(f"Failed to retrieve {url}. Status code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while processing {url}: {str(e)}")
# Out:
# Saved 1.zip
# Saved 2.zip
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_03_place.zip. Status code: 404
# Saved 4.zip
# Saved 5.zip
# Saved 6.zip
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_07_place.zip. Status code: 404
# Saved 8.zip
# Saved 9.zip
# Saved 10.zip
# Saved 11.zip
# Saved 12.zip
# Saved 13.zip
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_14_place.zip. Status code: 404
# Saved 15.zip
# Saved 16.zip
# Saved 17.zip
# Saved 18.zip
# Saved 19.zip
# Saved 20.zip
# Saved 21.zip
# Saved 22.zip
# Saved 23.zip
# Saved 24.zip
# Saved 25.zip
# Saved 26.zip
# Saved 27.zip
# Saved 28.zip
# Saved 29.zip
# Saved 30.zip
# Saved 31.zip
# Saved 32.zip
# Saved 33.zip
# Saved 34.zip
# Saved 35.zip
# Saved 36.zip
# Saved 37.zip
# Saved 38.zip
# Saved 39.zip
# Saved 40.zip
# Saved 41.zip
# Saved 42.zip
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_43_place.zip. Status code: 404
# Saved 44.zip
# Saved 45.zip
# Saved 46.zip
# Saved 47.zip
# Saved 48.zip
# Saved 49.zip
# Saved 50.zip
# Saved 51.zip
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_52_place.zip. Status code: 404
# Saved 53.zip
# Saved 54.zip
# Saved 55.zip
# Saved 56.zip
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_57_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_58_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_59_place.zip. Status code: 404
# Saved 60.zip
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_61_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_62_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_63_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_64_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_65_place.zip. Status code: 404
# Saved 66.zip
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_67_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_68_place.zip. Status code: 404
# Saved 69.zip
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_70_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_71_place.zip. Status code: 404
# Saved 72.zip
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_73_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_74_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_75_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_76_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_77_place.zip. Status code: 404
# Saved 78.zip
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_79_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_80_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_81_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_82_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_83_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_84_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_85_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_86_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_87_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_88_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_89_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_90_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_91_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_92_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_93_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_94_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_95_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_96_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_97_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_98_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_99_place.zip. Status code: 404
# Failed to retrieve https://www2.census.gov/geo/tiger/TIGER2022/PLACE/tl_2022_100_place.zip. Status code: 404
