# %%
# NOTEBOOK IMPORTS
import os, glob, warnings
import numpy as np
from shutil import copyfile, rmtree
from datetime import datetime

# IMAGE IMPORTS
from PIL import Image

# GIS IMPORTS
from affine import Affine
import pandas as pd
import rasterio as rio

# PLOTTING IMPORTS
import matplotlib.pyplot as plt

# CUSTOM UTILITIES
from IndexUtils import * 

Image.MAX_IMAGE_PIXELS = 933120000
warnings.filterwarnings("ignore")
# Out:
# c:\Users\fhace\miniforge-pypy3\envs\rectdnn\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
fn = r'C:\Users\fhace\Desktop\FIRMs\data\Indices\48071CIND0A.png'
TLNN = None
tiles, TLNN = findTiles(fn, model=TLNN, model_weights=r"C:\Users\fhace\Desktop\FIRMs\data\BBNN\curr_weights.pt")
# Out:
# image 1/1 C:\Users\fhace\Desktop\FIRMs\data\Indices\48071CIND0A.png: 736x1024 60 tiles, 1 county, 777.3ms
# Speed: 13.0ms preprocess, 777.3ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 1024)

# %%
tiles
# Out:
# {'48071C0450E': {'bbox': array([     8234.8,        4190,      9797.5,      5952.9]),
#   'data': <PIL.Image.Image image mode=L size=1563x1762>,
#   'coords': [4190.021435916424,
#    -8234.778213500977,
#    5952.858155965805,
#    -9797.476959228516]},
#  '4807100125E': {'bbox': array([     8122.4,      849.53,        9644,      2596.2]),
#   'data': <PIL.Image.Image image mode=L size=1521x1747>,
#   'coords': [849.5291478931904,
#    -8122.364902496338,
#    2596.206423640251,
#    -9643.959331512451]},
#  '4807100675E': {'bbox': array([     2512.9,      7775.5,      4039.8,        9525]),
#   'data': <PIL.Image.Image image mode=L size=1527x1750>,
#   'coords': [7775.529715418816,
#    -2512.850046157837,
#    9525.032275915146,
#    -4039.7595405578613]},
#  '4807100525E': {'bbox': array([     2427.1,      6092.8,      4007.5,      7849.5]),
#   'data': <PIL.Image.Image image mode=L size=1580x1757>,
#   'coords': [6092.788329720497,
#    -2427.054977416992,
# ...

# %%
fn = r'C:\Users\fhace\Desktop\FIRMs\data\Indices\48071CIND0A.png'
    getBBOX_coords(src)
# xs, ys = rio.transform.xy(src.transform, rows, cols)
